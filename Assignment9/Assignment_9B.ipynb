# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhakarmlal/EVA/blob/master/Assignment9/Assignment_9B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255

# %%
test_features = test_features.astype('float32')/255

# %%
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)

# %%
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# summarize dataset shape
print('Train', train_features.shape, train_labels.shape)
print('Test', (test_features.shape, test_labels.shape))
# summarize pixel values
print('Train', train_features.min(), train_features.max(), train_features.mean(), train_features.std())
print('Test', test_features.min(), test_features.max(), test_features.mean(), test_features.std())
# Out:
# Train (50000, 32, 32, 3) (50000, 10)
# Test ((10000, 32, 32, 3), (10000, 10))
# Train 0.0 1.0 0.4733649 0.25156906
# Test 0.0 1.0 0.47658524 0.25121963

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.imshow(train_features[1])

# %% [markdown]
# #### Performing Image Normalization

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True,data_format="channels_last")
# calculate mean on training dataset
datagen.fit(train_features)
# prepare an iterators to scale images
train_iterator = datagen.flow(train_features, train_labels, batch_size=128)
test_iterator = datagen.flow(test_features, test_features, batch_size=128)
print('Batches train=%d, test=%d' % (len(train_iterator), len(test_iterator)))
# confirm the scaling works
batchX, batchy = train_iterator.next()
print('Batch shape=%s, min=%.3f, max=%.3f' % (batchX.shape, batchX.min(), batchX.max()))
# Out:
# Batches train=391, test=79
# Batch shape=(128, 32, 32, 3), min=-1.989, max=2.127

# %%
from keras.callbacks import ModelCheckpoint

# %%
#Naming conventions to name convolution, batch normalization,maxpooling layers in the model
conv_name_base = 'convlayer_'
bn_name_base = 'bnlayer_'
mp_name_base = 'maxpooling_'

# %%
model2 = Sequential()
model2.add(Convolution2D(filters=32,kernel_size=(3,3),strides=1,padding='same',data_format='channels_last',input_shape=(32,32,3),use_bias=False,name = conv_name_base + '1')) #(3*3,32*32) of the form (effective global receptive field,output channel size )
model2.add(BatchNormalization(axis=3,name = bn_name_base + '1'))
model2.add(Activation('relu'))
#model2.add(Dropout(0.1)) #Removing Dropout as it is not good for cnn networks

model2.add(Convolution2D(filters=64,kernel_size=(3,3),strides=1,padding='same',use_bias=False,name = conv_name_base + '2')) #(5*5,32*32)
model2.add(BatchNormalization(axis=3,name = bn_name_base + '2'))
model2.add(Activation('relu'))
#model2.add(Dropout(0.1)) #Removing Dropout as it is not good for cnn networks

model2.add(Convolution2D(32,1,1,name = conv_name_base + '3')) #(5*5,32*32)
model2.add(BatchNormalization(axis=3,name = bn_name_base + '3'))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2,2),name = mp_name_base +  '1')) #(10*10,16*16)
#model2.add(Dropout(0.1)) #Removing Dropout as it is not good for cnn networks


model2.add(Convolution2D(filters=64,kernel_size=(3,3),strides=1,padding='same',use_bias=False,name = conv_name_base + '4')) #(12*12,16*16)
model2.add(BatchNormalization(axis=3,name = bn_name_base + '4'))
model2.add(Activation('relu'))
#model2.add(Dropout(0.1)) #Removing Dropout as it is not good for cnn networks

model2.add(Convolution2D(filters=128,kernel_size=(3,3),strides=1,padding='same',use_bias=False,name = conv_name_base + '5')) #(14*14,16*16)
model2.add(BatchNormalization(axis=3,name = bn_name_base + '5'))
model2.add(Activation('relu'))
#model2.add(Dropout(0.1))  #Removing Dropout as it is not good for cnn networks


model2.add(Convolution2D(32,1,1,name = conv_name_base + '6')) #(14*14,16*16)
model2.add(BatchNormalization(axis=3,name = bn_name_base + '6'))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2,2),name = mp_name_base +  '2')) #(28*28,8*8)
#model2.add(Dropout(0.1))  #Removing Dropout as it is not good for cnn networks


model2.add(Convolution2D(filters=32,kernel_size=(3,3),strides=1,padding='same',use_bias=False,name = conv_name_base + '7')) #(30*30,8*8)
model2.add(BatchNormalization(axis=3,name = bn_name_base + '7'))
model2.add(Activation('relu'))
#model2.add(Dropout(0.1))  #Removing Dropout as it is not good for cnn networks


model2.add(Convolution2D(filters=64,kernel_size=(3,3),strides=1,padding='same',use_bias=False,name = conv_name_base + '8')) #(32*32,8*8)
model2.add(BatchNormalization(axis=3,name = bn_name_base + '8'))
model2.add(Activation('relu'))
#model2.add(Dropout(0.1))  #Removing Dropout as it is not good for cnn networks



model2.add(Convolution2D(filters=10,kernel_size=(1,1),strides=1,padding='same',use_bias=False,name = conv_name_base + '9')) #(32*32,8*8)
model2.add(BatchNormalization(axis=3,name = bn_name_base + '9'))
model2.add(Activation('relu'))
#model2.add(Dropout(0.1))  #Removing Dropout as it is not good for cnn networks


        
model2.add(Convolution2D(num_classes,8,8,name = conv_name_base + '10')) #(40*40,10*1*1)
#passing the final activations through softmax layer.
model2.add(Flatten())
model2.add(Activation('softmax'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="convlayer_3")`
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="convlayer_6")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:57: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8), name="convlayer_10")`

# %%
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# convlayer_1 (Conv2D)         (None, 32, 32, 32)        864
# _________________________________________________________________
# bnlayer_1 (BatchNormalizatio (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_31 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# convlayer_2 (Conv2D)         (None, 32, 32, 64)        18432
# _________________________________________________________________
# bnlayer_2 (BatchNormalizatio (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_32 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# convlayer_3 (Conv2D)         (None, 32, 32, 32)        2080
# _________________________________________________________________
# bnlayer_3 (BatchNormalizatio (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_33 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# maxpooling_1 (MaxPooling2D)  (None, 16, 16, 32)        0
# _________________________________________________________________
# convlayer_4 (Conv2D)         (None, 16, 16, 64)        18432
# _________________________________________________________________
# bnlayer_4 (BatchNormalizatio (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_34 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# convlayer_5 (Conv2D)         (None, 16, 16, 128)       73728
# _________________________________________________________________
# bnlayer_5 (BatchNormalizatio (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_35 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# convlayer_6 (Conv2D)         (None, 16, 16, 32)        4128
# _________________________________________________________________
# bnlayer_6 (BatchNormalizatio (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_36 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# maxpooling_2 (MaxPooling2D)  (None, 8, 8, 32)          0
# _________________________________________________________________
# convlayer_7 (Conv2D)         (None, 8, 8, 32)          9216
# _________________________________________________________________
# bnlayer_7 (BatchNormalizatio (None, 8, 8, 32)          128
# _________________________________________________________________
# activation_37 (Activation)   (None, 8, 8, 32)          0
# _________________________________________________________________
# convlayer_8 (Conv2D)         (None, 8, 8, 64)          18432
# _________________________________________________________________
# bnlayer_8 (BatchNormalizatio (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_38 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# convlayer_9 (Conv2D)         (None, 8, 8, 10)          640
# _________________________________________________________________
# bnlayer_9 (BatchNormalizatio (None, 8, 8, 10)          40
# _________________________________________________________________
# activation_39 (Activation)   (None, 8, 8, 10)          0
# _________________________________________________________________
# convlayer_10 (Conv2D)        (None, 1, 1, 10)          6410
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_40 (Activation)   (None, 10)                0
# =================================================================
# Total params: 154,194
# Trainable params: 153,278
# Non-trainable params: 916
# _________________________________________________________________

# %%
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

model2.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.003), metrics=['accuracy'])

# %%
# checkpoint
filepath="./Assignment9_30_06_2019_evng-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint,LearningRateScheduler(scheduler, verbose=1)]

# %%
#Function which helps doing cutout
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
from keras.preprocessing.image import ImageDataGenerator
 # added for cutout
datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True,data_format='channels_last',preprocessing_function=get_random_eraser(v_l=0, v_h=1))


# train the model
start = time.time()
# Train the model
model_info = model2.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 70, 
                                 validation_data = (test_features, test_labels), verbose=1,callbacks = callbacks_list )
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model2))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=70)`
#   # This is added back by InteractiveShellApp.init_path()
# Epoch 1/70
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 390/390 [==============================] - 17s 43ms/step - loss: 1.4167 - acc: 0.4803 - val_loss: 1.6790 - val_acc: 0.5123
#
# Epoch 00001: val_acc improved from -inf to 0.51230, saving model to ./Assignment9_30_06_2019_evng-01-0.51.hdf5
# Epoch 2/70
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.9647 - acc: 0.6561 - val_loss: 1.1188 - val_acc: 0.6312
#
# Epoch 00002: val_acc improved from 0.51230 to 0.63120, saving model to ./Assignment9_30_06_2019_evng-02-0.63.hdf5
# Epoch 3/70
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 390/390 [==============================] - 11s 29ms/step - loss: 0.8109 - acc: 0.7107 - val_loss: 0.8885 - val_acc: 0.6875
#
# Epoch 00003: val_acc improved from 0.63120 to 0.68750, saving model to ./Assignment9_30_06_2019_evng-03-0.69.hdf5
# Epoch 4/70
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.7192 - acc: 0.7474 - val_loss: 1.0253 - val_acc: 0.6522
#
# Epoch 00004: val_acc did not improve from 0.68750
# Epoch 5/70
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0013181019.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.6505 - acc: 0.7708 - val_loss: 0.7736 - val_acc: 0.7362
#
# Epoch 00005: val_acc improved from 0.68750 to 0.73620, saving model to ./Assignment9_30_06_2019_evng-05-0.74.hdf5
# Epoch 6/70
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0011560694.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.5964 - acc: 0.7888 - val_loss: 0.8516 - val_acc: 0.7183
#
# Epoch 00006: val_acc did not improve from 0.73620
# Epoch 7/70
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0010295127.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.5486 - acc: 0.8067 - val_loss: 0.6724 - val_acc: 0.7730
#
# Epoch 00007: val_acc improved from 0.73620 to 0.77300, saving model to ./Assignment9_30_06_2019_evng-07-0.77.hdf5
# Epoch 8/70
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009279307.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.5033 - acc: 0.8237 - val_loss: 0.7251 - val_acc: 0.7665
#
# Epoch 00008: val_acc did not improve from 0.77300
# Epoch 9/70
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008445946.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.4710 - acc: 0.8340 - val_loss: 0.7594 - val_acc: 0.7529
#
# Epoch 00009: val_acc did not improve from 0.77300
# Epoch 10/70
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007749935.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.4370 - acc: 0.8478 - val_loss: 0.6869 - val_acc: 0.7801
#
# Epoch 00010: val_acc improved from 0.77300 to 0.78010, saving model to ./Assignment9_30_06_2019_evng-10-0.78.hdf5
# Epoch 11/70
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007159905.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.4062 - acc: 0.8571 - val_loss: 0.6502 - val_acc: 0.7950
#
# Epoch 00011: val_acc improved from 0.78010 to 0.79500, saving model to ./Assignment9_30_06_2019_evng-11-0.80.hdf5
# Epoch 12/70
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000665336.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3819 - acc: 0.8677 - val_loss: 0.6966 - val_acc: 0.7720
#
# Epoch 00012: val_acc did not improve from 0.79500
# Epoch 13/70
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0006213753.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3566 - acc: 0.8761 - val_loss: 0.6823 - val_acc: 0.7853
#
# Epoch 00013: val_acc did not improve from 0.79500
# Epoch 14/70
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005828638.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3315 - acc: 0.8854 - val_loss: 0.6509 - val_acc: 0.7933
#
# Epoch 00014: val_acc did not improve from 0.79500
# Epoch 15/70
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005488474.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.3117 - acc: 0.8919 - val_loss: 0.7967 - val_acc: 0.7698
#
# Epoch 00015: val_acc did not improve from 0.79500
# Epoch 16/70
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005185825.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.2906 - acc: 0.8982 - val_loss: 0.6658 - val_acc: 0.7983
#
# Epoch 00016: val_acc improved from 0.79500 to 0.79830, saving model to ./Assignment9_30_06_2019_evng-16-0.80.hdf5
# Epoch 17/70
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.000491481.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.2740 - acc: 0.9062 - val_loss: 0.7372 - val_acc: 0.7936
#
# Epoch 00017: val_acc did not improve from 0.79830
# Epoch 18/70
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0004670715.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.2630 - acc: 0.9100 - val_loss: 0.6804 - val_acc: 0.7961
#
# Epoch 00018: val_acc did not improve from 0.79830
# Epoch 19/70
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0004449718.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.2510 - acc: 0.9139 - val_loss: 0.6981 - val_acc: 0.7985
#
# Epoch 00019: val_acc improved from 0.79830 to 0.79850, saving model to ./Assignment9_30_06_2019_evng-19-0.80.hdf5
# Epoch 20/70
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.000424869.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.2416 - acc: 0.9186 - val_loss: 0.7184 - val_acc: 0.7988
#
# Epoch 00020: val_acc improved from 0.79850 to 0.79880, saving model to ./Assignment9_30_06_2019_evng-20-0.80.hdf5
# Epoch 21/70
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0004065041.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.2316 - acc: 0.9200 - val_loss: 0.7373 - val_acc: 0.7993
#
# Epoch 00021: val_acc improved from 0.79880 to 0.79930, saving model to ./Assignment9_30_06_2019_evng-21-0.80.hdf5
# Epoch 22/70
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.000389661.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.2232 - acc: 0.9234 - val_loss: 0.7340 - val_acc: 0.8003
#
# Epoch 00022: val_acc improved from 0.79930 to 0.80030, saving model to ./Assignment9_30_06_2019_evng-22-0.80.hdf5
# Epoch 23/70
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0003741581.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.2155 - acc: 0.9272 - val_loss: 0.7266 - val_acc: 0.7972
#
# Epoch 00023: val_acc did not improve from 0.80030
# Epoch 24/70
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0003598417.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.2063 - acc: 0.9304 - val_loss: 0.6919 - val_acc: 0.8126
#
# Epoch 00024: val_acc improved from 0.80030 to 0.81260, saving model to ./Assignment9_30_06_2019_evng-24-0.81.hdf5
# Epoch 25/70
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003465804.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1994 - acc: 0.9339 - val_loss: 0.7076 - val_acc: 0.8076
#
# Epoch 00025: val_acc did not improve from 0.81260
# Epoch 26/70
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003342618.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1917 - acc: 0.9351 - val_loss: 0.7226 - val_acc: 0.8036
#
# Epoch 00026: val_acc did not improve from 0.81260
# Epoch 27/70
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003227889.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1861 - acc: 0.9378 - val_loss: 0.7174 - val_acc: 0.8046
#
# Epoch 00027: val_acc did not improve from 0.81260
# Epoch 28/70
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003120774.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1847 - acc: 0.9388 - val_loss: 0.7427 - val_acc: 0.8082
#
# Epoch 00028: val_acc did not improve from 0.81260
# Epoch 29/70
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000302054.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1796 - acc: 0.9400 - val_loss: 0.7838 - val_acc: 0.7981
#
# Epoch 00029: val_acc did not improve from 0.81260
# Epoch 30/70
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0002926544.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1761 - acc: 0.9410 - val_loss: 0.7400 - val_acc: 0.8098
#
# Epoch 00030: val_acc did not improve from 0.81260
# Epoch 31/70
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002838221.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1722 - acc: 0.9429 - val_loss: 0.7482 - val_acc: 0.8069
#
# Epoch 00031: val_acc did not improve from 0.81260
# Epoch 32/70
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002755074.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1698 - acc: 0.9436 - val_loss: 0.7826 - val_acc: 0.7988
#
# Epoch 00032: val_acc did not improve from 0.81260
# Epoch 33/70
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000267666.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1636 - acc: 0.9464 - val_loss: 0.7636 - val_acc: 0.8097
#
# Epoch 00033: val_acc did not improve from 0.81260
# Epoch 34/70
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002602585.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1599 - acc: 0.9470 - val_loss: 0.7982 - val_acc: 0.8045
#
# Epoch 00034: val_acc did not improve from 0.81260
# Epoch 35/70
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00025325.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1579 - acc: 0.9485 - val_loss: 0.7620 - val_acc: 0.8081
#
# Epoch 00035: val_acc did not improve from 0.81260
# Epoch 36/70
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002466091.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1560 - acc: 0.9481 - val_loss: 0.7353 - val_acc: 0.8102
#
# Epoch 00036: val_acc did not improve from 0.81260
# Epoch 37/70
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002403076.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1509 - acc: 0.9500 - val_loss: 0.7576 - val_acc: 0.8117
#
# Epoch 00037: val_acc did not improve from 0.81260
# Epoch 38/70
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0002343201.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1492 - acc: 0.9510 - val_loss: 0.7876 - val_acc: 0.8047
#
# Epoch 00038: val_acc did not improve from 0.81260
# Epoch 39/70
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0002286237.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1446 - acc: 0.9525 - val_loss: 0.7772 - val_acc: 0.8099
#
# Epoch 00039: val_acc did not improve from 0.81260
# Epoch 40/70
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0002231977.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1495 - acc: 0.9509 - val_loss: 0.7499 - val_acc: 0.8090
#
# Epoch 00040: val_acc did not improve from 0.81260
# Epoch 41/70
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0002180233.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1457 - acc: 0.9525 - val_loss: 0.7492 - val_acc: 0.8094
#
# Epoch 00041: val_acc did not improve from 0.81260
# Epoch 42/70
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0002130833.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1407 - acc: 0.9539 - val_loss: 0.7965 - val_acc: 0.8060
#
# Epoch 00042: val_acc did not improve from 0.81260
# Epoch 43/70
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0002083623.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1402 - acc: 0.9541 - val_loss: 0.8081 - val_acc: 0.8070
#
# Epoch 00043: val_acc did not improve from 0.81260
# Epoch 44/70
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0002038459.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1364 - acc: 0.9550 - val_loss: 0.7735 - val_acc: 0.8085
#
# Epoch 00044: val_acc did not improve from 0.81260
# Epoch 45/70
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001995211.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1383 - acc: 0.9544 - val_loss: 0.7889 - val_acc: 0.8101
#
# Epoch 00045: val_acc did not improve from 0.81260
# Epoch 46/70
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001953761.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1325 - acc: 0.9562 - val_loss: 0.7734 - val_acc: 0.8131
#
# Epoch 00046: val_acc improved from 0.81260 to 0.81310, saving model to ./Assignment9_30_06_2019_evng-46-0.81.hdf5
# Epoch 47/70
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001913998.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1365 - acc: 0.9551 - val_loss: 0.7751 - val_acc: 0.8098
#
# Epoch 00047: val_acc did not improve from 0.81310
# Epoch 48/70
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001875821.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1312 - acc: 0.9565 - val_loss: 0.7903 - val_acc: 0.8071
#
# Epoch 00048: val_acc did not improve from 0.81310
# Epoch 49/70
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001839137.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1367 - acc: 0.9543 - val_loss: 0.8047 - val_acc: 0.8094
#
# Epoch 00049: val_acc did not improve from 0.81310
# Epoch 50/70
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.000180386.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1320 - acc: 0.9567 - val_loss: 0.8154 - val_acc: 0.8067
#
# Epoch 00050: val_acc did not improve from 0.81310
# Epoch 51/70
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001769912.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1295 - acc: 0.9578 - val_loss: 0.7785 - val_acc: 0.8125
#
# Epoch 00051: val_acc did not improve from 0.81310
# Epoch 52/70
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001737217.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1253 - acc: 0.9586 - val_loss: 0.7744 - val_acc: 0.8124
#
# Epoch 00052: val_acc did not improve from 0.81310
# Epoch 53/70
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001705708.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1313 - acc: 0.9561 - val_loss: 0.8192 - val_acc: 0.8081
#
# Epoch 00053: val_acc did not improve from 0.81310
# Epoch 54/70
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001675322.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1221 - acc: 0.9591 - val_loss: 0.7964 - val_acc: 0.8144
#
# Epoch 00054: val_acc improved from 0.81310 to 0.81440, saving model to ./Assignment9_30_06_2019_evng-54-0.81.hdf5
# Epoch 55/70
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001646.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1243 - acc: 0.9595 - val_loss: 0.7930 - val_acc: 0.8126
#
# Epoch 00055: val_acc did not improve from 0.81440
# Epoch 56/70
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001617687.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1259 - acc: 0.9582 - val_loss: 0.7955 - val_acc: 0.8121
#
# Epoch 00056: val_acc did not improve from 0.81440
# Epoch 57/70
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001590331.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1219 - acc: 0.9593 - val_loss: 0.7808 - val_acc: 0.8094
#
# Epoch 00057: val_acc did not improve from 0.81440
# Epoch 58/70
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001563885.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1250 - acc: 0.9576 - val_loss: 0.8214 - val_acc: 0.8078
#
# Epoch 00058: val_acc did not improve from 0.81440
# Epoch 59/70
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001538304.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1202 - acc: 0.9605 - val_loss: 0.8059 - val_acc: 0.8130
#
# Epoch 00059: val_acc did not improve from 0.81440
# Epoch 60/70
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001513546.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1173 - acc: 0.9621 - val_loss: 0.8097 - val_acc: 0.8114
#
# Epoch 00060: val_acc did not improve from 0.81440
# Epoch 61/70
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001489573.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1192 - acc: 0.9601 - val_loss: 0.8127 - val_acc: 0.8135
#
# Epoch 00061: val_acc did not improve from 0.81440
# Epoch 62/70
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001466347.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1164 - acc: 0.9616 - val_loss: 0.8115 - val_acc: 0.8156
#
# Epoch 00062: val_acc improved from 0.81440 to 0.81560, saving model to ./Assignment9_30_06_2019_evng-62-0.82.hdf5
# Epoch 63/70
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001443835.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1177 - acc: 0.9606 - val_loss: 0.8053 - val_acc: 0.8148
#
# Epoch 00063: val_acc did not improve from 0.81560
# Epoch 64/70
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001422003.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1172 - acc: 0.9610 - val_loss: 0.8366 - val_acc: 0.8095
#
# Epoch 00064: val_acc did not improve from 0.81560
# Epoch 65/70
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001400822.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1094 - acc: 0.9631 - val_loss: 0.8056 - val_acc: 0.8127
#
# Epoch 00065: val_acc did not improve from 0.81560
# Epoch 66/70
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001380262.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1137 - acc: 0.9617 - val_loss: 0.8313 - val_acc: 0.8076
#
# Epoch 00066: val_acc did not improve from 0.81560
# Epoch 67/70
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001360297.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1111 - acc: 0.9628 - val_loss: 0.8053 - val_acc: 0.8143
#
# Epoch 00067: val_acc did not improve from 0.81560
# Epoch 68/70
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001340902.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1100 - acc: 0.9634 - val_loss: 0.7991 - val_acc: 0.8156
#
# Epoch 00068: val_acc did not improve from 0.81560
# Epoch 69/70
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001322052.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1092 - acc: 0.9636 - val_loss: 0.8004 - val_acc: 0.8154
#
# Epoch 00069: val_acc did not improve from 0.81560
# Epoch 70/70
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001303724.
# 390/390 [==============================] - 12s 30ms/step - loss: 0.1126 - acc: 0.9622 - val_loss: 0.8572 - val_acc: 0.8093
#
# Epoch 00070: val_acc did not improve from 0.81560
# Model took 828.39 seconds to train
# Accuracy on test data is: 80.93

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
#root_dir = "/content/gdrive/My Drive/"
#base_dir = root_dir + 'EVA_assignment_9/'
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive"
# Out:
# 'My Drive'

# %%
# Saving the best model from Google colab to Google drive
# !cp  "./Assignment9_30_06_2019_evng-54-0.81.hdf5"  "/content/gdrive/My Drive/Assignment9_30_06_2019_evng-54-0.81.hdf5"

# %%
# Saving the best model from Google drive  to Google colab
#!cp  "/content/gdrive/My Drive/Assignment9_27_06_2019_evng-67-0.85.hdf5" "./Assignment9_27_06_2019_evng-67-0.85.hdf5"

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True,data_format="channels_last")
# calculate mean on training dataset
datagen.fit(train_features)
# prepare an iterators to scale images
train_iterator = datagen.flow(train_features, train_labels, batch_size=128)
test_iterator = datagen.flow(test_features, test_features, batch_size=128)
print('Batches train=%d, test=%d' % (len(train_iterator), len(test_iterator)))
# confirm the scaling works
batchX, batchy = train_iterator.next()
print('Batch shape=%s, min=%.3f, max=%.3f' % (batchX.shape, batchX.min(), batchX.max()))
# Out:
# Batches train=391, test=79
# Batch shape=(128, 32, 32, 3), min=-1.989, max=2.127

# %%
#Cifar stats mean and standard deviation along the RGB channels
cifar_stats = ([0.491, 0.482, 0.447], [0.247, 0.243, 0.261])

# %%
datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True,data_format='channels_last')

# %%
model2.load_weights("Assignment9_30_06_2019_evng-54-0.81.hdf5")

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True,data_format='channels_last')

# %%
datagen.fit(train_features)

# %%
datagen.mean
# Out:
# array([[[0.4914009 , 0.48215896, 0.4465308 ]]], dtype=float32)

# %%
datagen.std
# Out:
# array([[[0.24703272, 0.2434843 , 0.26158753]]], dtype=float32)

# %%
from skimage.util import img_as_float

# %%
def Gradcom_image(input_img,datagen,model):
  image_array = image.img_to_array(input_img)
  image_array = np.expand_dims(image_array, axis=0)
  
  #image_array = datagen.standardize(image_array) #standarizing the image with RGB channel mean and standard deviation
  image_array = preprocess_input(image_array)
  
  preds = model.predict(image_array)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("convlayer_8") # getting activation channels of the convolution layer before prediction layer
  
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([image_array])
  for i in range(64):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
    
    
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  
  #print(heatmap.shape)
  heatmap = cv2.resize(heatmap, (input_img.shape[1], input_img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  print(heatmap.shape)
  print(input_img.shape)
  print(input_img.dtype)
  print(heatmap.dtype)
  
  superimposed_img = cv2.addWeighted(input_img, 0.6, heatmap, 0.4, 0)
  
  return superimposed_img

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import keras.backend as K
import numpy as np
import cv2
import sys

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
selected_classes_count = 4
fig = plt.figure(figsize=(8,8))
no_cols = 1
for each_class in range(selected_classes_count):
    ax = fig.add_subplot(selected_classes_count, 2, no_cols, xticks=[], yticks=[])
    no_cols = no_cols + 1
    idx = np.where(test_labels[:]== each_class)[0]
    features_idx = test_features[idx,::]
    img_num = no_cols  #Removing randomness and fixing the images
    im = features_idx[img_num]
    #ax.set_title(class_names[each_class])
    plt.imshow(im)
    #print("raw_image_shape")
    #print(im.shape)
    ax.set_title(class_names[each_class])
    ax1 = fig.add_subplot(selected_classes_count, 2, no_cols, xticks=[], yticks=[])
    no_cols = no_cols + 1
    img2 = Gradcom_image(im,datagen,model2)
    plt.imshow(img2)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# (32, 32, 3)
# (32, 32, 3)
# uint8
# uint8
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# (32, 32, 3)
# (32, 32, 3)
# uint8
# uint8
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# (32, 32, 3)
# (32, 32, 3)
# uint8
# uint8
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# (32, 32, 3)
# (32, 32, 3)
# uint8
# uint8

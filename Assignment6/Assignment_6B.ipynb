# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhakarmlal/EVA/blob/master/Assignment6/Assignment_6B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# summarize dataset shape
print('Train', train_features.shape, train_labels.shape)
print('Test', (test_features.shape, test_labels.shape))
# summarize pixel values
print('Train', train_features.min(), train_features.max(), train_features.mean(), train_features.std())
print('Test', test_features.min(), test_features.max(), test_features.mean(), test_features.std())
# Out:
# Train (50000, 32, 32, 3) (50000, 10)
# Test ((10000, 32, 32, 3), (10000, 10))
# Train 0.0 1.0 0.4733649 0.25156906
# Test 0.0 1.0 0.47658524 0.25121963

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.imshow(train_features[1])

# %% [markdown]
# #### Performing Image Normalization

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
from keras.callbacks import ModelCheckpoint

# %%
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# %%
# checkpoint
filepath="./Assignment6_07_06_2019_evng-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint,LearningRateScheduler(scheduler, verbose=1)]

# %%
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, SeparableConv2D
from keras.layers.merge import concatenate
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Activation, merge
from keras.layers.convolutional import Conv2D, MaxPooling2D, ZeroPadding2D, AveragePooling2D

# %%
input_shape = (32,32)+(3,)
img_input = Input(shape = input_shape)
x = Conv2D(32,3,strides=1,padding='same',data_format='channels_last',use_bias=False)(img_input)#(3*3,32*32) of the form (effective global receptive field,output channel size )
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

x = Conv2D(32,kernel_size=(3,1),strides=1,padding = 'same',data_format='channels_last',use_bias=False)(x) 
x = Conv2D(64,kernel_size=(1,3),strides=1,padding = 'same',data_format='channels_last',use_bias=False)(x) #(5*5,32*32)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

#adding bottleneck layer
x = Conv2D(32, 1,strides=1,data_format='channels_last',use_bias=False )(x) #(5*5,32*32)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2,2),data_format='channels_last')(x) #(10*10,16*16)
x = Dropout(0.1)(x)


x = Conv2D(64,3,strides=1,padding='same',data_format='channels_last',dilation_rate = 1,use_bias=False)(x) #(12*12,16*16)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

skip_tensor = x

x = Conv2D(128,3,strides=1,padding = 'same',data_format='channels_last',dilation_rate = 2,use_bias=False)(x) #(16*16,16*16)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

x = concatenate([skip_tensor, x])


x = Conv2D(32,1,strides=1,data_format='channels_last',use_bias=False)(x) #(20*20,32*32)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2,2),data_format='channels_last')(x) #(32*32,8*8)
x = Dropout(0.1)(x)                
          
x = Conv2D(32,3,strides=1,padding='same',data_format='channels_last',use_bias=False)(x) #(34*34,8*8)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)
                
x = Conv2D(64,3,strides=1,padding='same',data_format='channels_last',use_bias=False)(x) #(36*36,8*8)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)  
x = Dropout(0.1)(x)

x = Conv2D(10, 1,strides=1,data_format='channels_last',use_bias=False)(x) #(36*36,8*8)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)
                
x = Conv2D(num_classes,(8,8))(x) #(36*36,8*38)
x = Flatten()(x)
output = Activation('softmax')(x)

# %%
model = Model(inputs=img_input, outputs=output)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 32)   864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 32)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 32)   3072        dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   6144        conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 64)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 32)   2048        dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16, 16, 32)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   18432       dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 64)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 128)  73728       dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 128)  0           activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 192)  0           dropout_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 32)   6144        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 32)   128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 32)     0           activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 8, 8, 32)     0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 32)     9216        dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 32)     128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 32)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 8, 8, 32)     0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     18432       dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 8, 8, 64)     0           activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 10)     640         dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 10)     40          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 10)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 8, 8, 10)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 1, 1, 10)     6410        dropout_18[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 10)           0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 10)           0           flatten_2[0][0]
# ==================================================================================================
# Total params: 146,962
# Trainable params: 146,046
# Non-trainable params: 916
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %%
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# %%
# checkpoint
filepath="./Assignment6_12_06_2019-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint,LearningRateScheduler(scheduler, verbose=1)]

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True,data_format='channels_last')


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1,callbacks = callbacks_list )
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=50)`
#   # This is added back by InteractiveShellApp.init_path()
# Epoch 1/50
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 390/390 [==============================] - 37s 94ms/step - loss: 1.4337 - acc: 0.4745 - val_loss: 1.4561 - val_acc: 0.5117
#
# Epoch 00001: val_acc improved from -inf to 0.51170, saving model to ./Assignment6_12_06_2019-01-0.51.hdf5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.9768 - acc: 0.6499 - val_loss: 1.0511 - val_acc: 0.6395
#
# Epoch 00002: val_acc improved from 0.51170 to 0.63950, saving model to ./Assignment6_12_06_2019-02-0.64.hdf5
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.8235 - acc: 0.7081 - val_loss: 0.7967 - val_acc: 0.7194
#
# Epoch 00003: val_acc improved from 0.63950 to 0.71940, saving model to ./Assignment6_12_06_2019-03-0.72.hdf5
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.7273 - acc: 0.7430 - val_loss: 0.7866 - val_acc: 0.7225
#
# Epoch 00004: val_acc improved from 0.71940 to 0.72250, saving model to ./Assignment6_12_06_2019-04-0.72.hdf5
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0013181019.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.6724 - acc: 0.7618 - val_loss: 0.9241 - val_acc: 0.6873
#
# Epoch 00005: val_acc did not improve from 0.72250
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0011560694.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.6247 - acc: 0.7788 - val_loss: 0.8149 - val_acc: 0.7204
#
# Epoch 00006: val_acc did not improve from 0.72250
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0010295127.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.5936 - acc: 0.7913 - val_loss: 0.6673 - val_acc: 0.7670
#
# Epoch 00007: val_acc improved from 0.72250 to 0.76700, saving model to ./Assignment6_12_06_2019-07-0.77.hdf5
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009279307.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.5612 - acc: 0.8005 - val_loss: 0.6938 - val_acc: 0.7680
#
# Epoch 00008: val_acc improved from 0.76700 to 0.76800, saving model to ./Assignment6_12_06_2019-08-0.77.hdf5
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008445946.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.5369 - acc: 0.8124 - val_loss: 0.6103 - val_acc: 0.7898
#
# Epoch 00009: val_acc improved from 0.76800 to 0.78980, saving model to ./Assignment6_12_06_2019-09-0.79.hdf5
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007749935.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.5126 - acc: 0.8191 - val_loss: 0.5980 - val_acc: 0.7914
#
# Epoch 00010: val_acc improved from 0.78980 to 0.79140, saving model to ./Assignment6_12_06_2019-10-0.79.hdf5
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007159905.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4908 - acc: 0.8270 - val_loss: 0.6326 - val_acc: 0.7859
#
# Epoch 00011: val_acc did not improve from 0.79140
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000665336.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4747 - acc: 0.8327 - val_loss: 0.5624 - val_acc: 0.8053
#
# Epoch 00012: val_acc improved from 0.79140 to 0.80530, saving model to ./Assignment6_12_06_2019-12-0.81.hdf5
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0006213753.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4580 - acc: 0.8374 - val_loss: 0.5864 - val_acc: 0.7967
#
# Epoch 00013: val_acc did not improve from 0.80530
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005828638.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4472 - acc: 0.8421 - val_loss: 0.5773 - val_acc: 0.8060
#
# Epoch 00014: val_acc improved from 0.80530 to 0.80600, saving model to ./Assignment6_12_06_2019-14-0.81.hdf5
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005488474.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4359 - acc: 0.8452 - val_loss: 0.6135 - val_acc: 0.7933
#
# Epoch 00015: val_acc did not improve from 0.80600
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005185825.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4211 - acc: 0.8510 - val_loss: 0.5921 - val_acc: 0.7982
#
# Epoch 00016: val_acc did not improve from 0.80600
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.000491481.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4167 - acc: 0.8532 - val_loss: 0.5855 - val_acc: 0.8065
#
# Epoch 00017: val_acc improved from 0.80600 to 0.80650, saving model to ./Assignment6_12_06_2019-17-0.81.hdf5
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0004670715.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4041 - acc: 0.8561 - val_loss: 0.5629 - val_acc: 0.8108
#
# Epoch 00018: val_acc improved from 0.80650 to 0.81080, saving model to ./Assignment6_12_06_2019-18-0.81.hdf5
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0004449718.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.4005 - acc: 0.8575 - val_loss: 0.5633 - val_acc: 0.8117
#
# Epoch 00019: val_acc improved from 0.81080 to 0.81170, saving model to ./Assignment6_12_06_2019-19-0.81.hdf5
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.000424869.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3881 - acc: 0.8629 - val_loss: 0.5215 - val_acc: 0.8230
#
# Epoch 00020: val_acc improved from 0.81170 to 0.82300, saving model to ./Assignment6_12_06_2019-20-0.82.hdf5
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0004065041.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3825 - acc: 0.8651 - val_loss: 0.5436 - val_acc: 0.8172
#
# Epoch 00021: val_acc did not improve from 0.82300
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.000389661.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3743 - acc: 0.8671 - val_loss: 0.5551 - val_acc: 0.8143
#
# Epoch 00022: val_acc did not improve from 0.82300
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0003741581.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3696 - acc: 0.8701 - val_loss: 0.5331 - val_acc: 0.8239
#
# Epoch 00023: val_acc improved from 0.82300 to 0.82390, saving model to ./Assignment6_12_06_2019-23-0.82.hdf5
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0003598417.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3619 - acc: 0.8720 - val_loss: 0.5578 - val_acc: 0.8165
#
# Epoch 00024: val_acc did not improve from 0.82390
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003465804.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3602 - acc: 0.8713 - val_loss: 0.5165 - val_acc: 0.8276
#
# Epoch 00025: val_acc improved from 0.82390 to 0.82760, saving model to ./Assignment6_12_06_2019-25-0.83.hdf5
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003342618.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3542 - acc: 0.8744 - val_loss: 0.5223 - val_acc: 0.8258
#
# Epoch 00026: val_acc did not improve from 0.82760
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003227889.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3524 - acc: 0.8766 - val_loss: 0.5113 - val_acc: 0.8302
#
# Epoch 00027: val_acc improved from 0.82760 to 0.83020, saving model to ./Assignment6_12_06_2019-27-0.83.hdf5
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003120774.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3435 - acc: 0.8782 - val_loss: 0.5369 - val_acc: 0.8243
#
# Epoch 00028: val_acc did not improve from 0.83020
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000302054.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3405 - acc: 0.8790 - val_loss: 0.5481 - val_acc: 0.8169
#
# Epoch 00029: val_acc did not improve from 0.83020
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0002926544.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3359 - acc: 0.8813 - val_loss: 0.5258 - val_acc: 0.8283
#
# Epoch 00030: val_acc did not improve from 0.83020
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002838221.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3308 - acc: 0.8810 - val_loss: 0.5128 - val_acc: 0.8303
#
# Epoch 00031: val_acc improved from 0.83020 to 0.83030, saving model to ./Assignment6_12_06_2019-31-0.83.hdf5
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002755074.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3283 - acc: 0.8835 - val_loss: 0.5054 - val_acc: 0.8338
#
# Epoch 00032: val_acc improved from 0.83030 to 0.83380, saving model to ./Assignment6_12_06_2019-32-0.83.hdf5
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000267666.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3224 - acc: 0.8846 - val_loss: 0.5550 - val_acc: 0.8198
#
# Epoch 00033: val_acc did not improve from 0.83380
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002602585.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3161 - acc: 0.8867 - val_loss: 0.5182 - val_acc: 0.8255
#
# Epoch 00034: val_acc did not improve from 0.83380
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00025325.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3189 - acc: 0.8861 - val_loss: 0.5391 - val_acc: 0.8224
#
# Epoch 00035: val_acc did not improve from 0.83380
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002466091.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3154 - acc: 0.8868 - val_loss: 0.5231 - val_acc: 0.8326
#
# Epoch 00036: val_acc did not improve from 0.83380
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002403076.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3089 - acc: 0.8892 - val_loss: 0.5522 - val_acc: 0.8239
#
# Epoch 00037: val_acc did not improve from 0.83380
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0002343201.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3072 - acc: 0.8908 - val_loss: 0.5439 - val_acc: 0.8258
#
# Epoch 00038: val_acc did not improve from 0.83380
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0002286237.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3050 - acc: 0.8909 - val_loss: 0.5373 - val_acc: 0.8260
#
# Epoch 00039: val_acc did not improve from 0.83380
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0002231977.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.3041 - acc: 0.8921 - val_loss: 0.5073 - val_acc: 0.8377
#
# Epoch 00040: val_acc improved from 0.83380 to 0.83770, saving model to ./Assignment6_12_06_2019-40-0.84.hdf5
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0002180233.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2993 - acc: 0.8932 - val_loss: 0.4971 - val_acc: 0.8383
#
# Epoch 00041: val_acc improved from 0.83770 to 0.83830, saving model to ./Assignment6_12_06_2019-41-0.84.hdf5
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0002130833.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2973 - acc: 0.8934 - val_loss: 0.5519 - val_acc: 0.8210
#
# Epoch 00042: val_acc did not improve from 0.83830
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0002083623.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2960 - acc: 0.8952 - val_loss: 0.5126 - val_acc: 0.8289
#
# Epoch 00043: val_acc did not improve from 0.83830
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0002038459.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2913 - acc: 0.8960 - val_loss: 0.5280 - val_acc: 0.8310
#
# Epoch 00044: val_acc did not improve from 0.83830
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001995211.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2907 - acc: 0.8956 - val_loss: 0.5207 - val_acc: 0.8321
#
# Epoch 00045: val_acc did not improve from 0.83830
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001953761.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2900 - acc: 0.8973 - val_loss: 0.5432 - val_acc: 0.8267
#
# Epoch 00046: val_acc did not improve from 0.83830
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001913998.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2890 - acc: 0.8977 - val_loss: 0.5221 - val_acc: 0.8333
#
# Epoch 00047: val_acc did not improve from 0.83830
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001875821.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2881 - acc: 0.8960 - val_loss: 0.5490 - val_acc: 0.8233
#
# Epoch 00048: val_acc did not improve from 0.83830
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001839137.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2851 - acc: 0.8986 - val_loss: 0.5504 - val_acc: 0.8257
#
# Epoch 00049: val_acc did not improve from 0.83830
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.000180386.
# 390/390 [==============================] - 34s 88ms/step - loss: 0.2740 - acc: 0.9014 - val_loss: 0.5425 - val_acc: 0.8266
#
# Epoch 00050: val_acc did not improve from 0.83830
# Model took 1726.95 seconds to train
# Accuracy on test data is: 82.66

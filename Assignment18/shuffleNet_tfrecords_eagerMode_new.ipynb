# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhakarmlal/EVA/blob/master/Assignment18/shuffleNet_tfrecords_eagerMode_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# !ls
# Out:
#      <input type="file" id="files-99c648be-ba91-49b9-887f-1915314957f9" name="files[]" multiple disabled />
#      <output id="result-99c648be-ba91-49b9-887f-1915314957f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TFRecords_cifar10.py to TFRecords_cifar10.py
# sample_data  TFRecords_cifar10.py

# %%
# !ls
# Out:
# cifar-10-batches-py	sample_data	      train.tfrecords
# cifar-10-python.tar.gz	TFRecords_cifar10.py  validation.tfrecords

# %%
# !python TFRecords_cifar10.py
# Out:
# Download from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz and extract.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From TFRecords_cifar10.py:42: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded cifar-10-python.tar.gz 170498071 bytes.
# Generating train.tfrecords
# WARNING:tensorflow:From TFRecords_cifar10.py:76: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From TFRecords_cifar10.py:65: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# data_dict 4
# data_dict 4
# data_dict 4
# data_dict 4
# data_dict 4
# Generating validation.tfrecords
# data_dict 4
# Done!

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time, math

tf.enable_eager_execution()

filename_train = 'train.tfrecords' 
filename_test = 'validation.tfrecords' 
HEIGHT = 32
WIDTH = 32
DEPTH = 3

# %%
def normalize(image):
  """Convert `image` from [0, 255] -> [0, 1] floats."""
  image = tf.cast(image, tf.float32) * (1. / 255)
  return image  

def preprocess(image):
    """Preprocess a single image in [height, width, depth] layout."""
    # Pad 4 pixels on each dimension of feature map, done in mini-batch
    image = tf.image.resize_image_with_crop_or_pad(image, 40, 40)
    image = tf.random_crop(image, [HEIGHT, WIDTH, DEPTH])
    image = tf.image.random_flip_left_right(image)
    return image
def replace_slice(input_: tf.Tensor, replacement, begin) -> tf.Tensor:
    inp_shape = tf.shape(input_)
    size = tf.shape(replacement)
    padding = tf.stack([begin, inp_shape - (begin + size)], axis=1)
    replacement_pad = tf.pad(replacement, padding)
    mask = tf.pad(tf.ones_like(replacement, dtype=tf.bool), padding)
    return tf.where(mask, replacement_pad, input_)
def cutout(x: tf.Tensor, h: int=8, w: int=8, c: int = 3) -> tf.Tensor:
    shape = tf.shape(x)
    x0 = tf.random.uniform([], 0, shape[0] + 1 - h, dtype=tf.int32)
    y0 = tf.random.uniform([], 0, shape[1] + 1 - w, dtype=tf.int32)
    
    x = replace_slice(x, tf.random.uniform([h, w, c], dtype = tf.float32), [x0, y0, 0])
#     x = replace_slice(x, tf.zeros([h, w, c], dtype = tf.float32), [x0, y0, 0])
    return x

# %%
def parser(serialized_example):
    """Parses a single tf.Example into image and label tensors."""
    # Dimensions of the images in the CIFAR-10 dataset.
    # See http://www.cs.toronto.edu/~kriz/cifar.html for a description of the
    # input format.
    features = tf.parse_single_example(
        serialized_example,
        features={
            'image': tf.FixedLenFeature([], tf.string),
            'label': tf.FixedLenFeature([], tf.int64),
        })
    image = tf.decode_raw(features['image'], tf.uint8)
    image.set_shape([DEPTH * HEIGHT * WIDTH])
    image = normalize(image)

    # Reshape from [depth * height * width] to [depth, height, width].
    image = tf.cast(
        tf.transpose(tf.reshape(image, [DEPTH, HEIGHT, WIDTH]), [1, 2, 0]),
        tf.float32)
    label = tf.cast(features['label'], tf.int32)
    label = tf.one_hot(label, 10)

    # Custom preprocessing.
    image = preprocess(image)
    image = cutout(image)

    return image, label  
  
def parser_test(serialized_example):
    """Parses a single tf.Example into image and label tensors."""
    # Dimensions of the images in the CIFAR-10 dataset.
    # See http://www.cs.toronto.edu/~kriz/cifar.html for a description of the
    # input format.
    features = tf.parse_single_example(
        serialized_example,
        features={
            'image': tf.FixedLenFeature([], tf.string),
            'label': tf.FixedLenFeature([], tf.int64),
        })
    image = tf.decode_raw(features['image'], tf.uint8)
    image.set_shape([DEPTH * HEIGHT * WIDTH])
    image = normalize(image)

    # Reshape from [depth * height * width] to [depth, height, width].
    image = tf.cast(
        tf.transpose(tf.reshape(image, [DEPTH, HEIGHT, WIDTH]), [1, 2, 0]),
        tf.float32)
    label = tf.cast(features['label'], tf.int32)
    label = tf.one_hot(label, 10)

    return image, label

# %%
# Hyperparameters
num_classes = 10
dropout_rate = 0.1
batch_size = 512
num_epochs = 200

# %%
# -----------TRAIN TFRecords
# dataset_train = tf.data.TFRecordDataset(filename_train).repeat(1)
# # dataset_test = dataset_train.apply(tf.contrib.data.shuffle_and_repeat(1,40000))
# # dataset_test = dataset_train.apply(tf.contrib.data.map_and_batch(parser,batch_size))
# dataset_train = dataset_train.map(parser, num_parallel_calls=batch_size)
# dataset_train = dataset_train.shuffle(buffer_size=40000) 

# # Batch it up.
# dataset_train = dataset_train.batch(batch_size)
# # iterator = dataset_train.make_one_shot_iterator()
# # image_batch, label_batch = iterator.get_next()

# -------------TEST TFRecords
dataset_test = tf.data.TFRecordDataset(filename_test).repeat(1)
# dataset_test = dataset_test.apply(tf.contrib.data.shuffle_and_repeat(1,10000))
# dataset_test = dataset_test.apply(tf.contrib.data.map_and_batch(parser,batch_size))

dataset_test = dataset_test.map(parser_test, num_parallel_calls=batch_size)
dataset_test = dataset_test.shuffle(buffer_size=10000) 

# Batch it up.
dataset_test = dataset_test.batch(batch_size)
# iterator = dataset_train.make_one_shot_iterator()
# image_batch, label_batch = iterator.get_next()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.

# %%
import tensorflow as tf

def _stage(tensor, nb_groups, in_channels, out_channels, repeat):
    x = _shufflenet_unit(tensor, nb_groups, in_channels, out_channels, 2)

    for _ in range(repeat):
        x = _shufflenet_unit(x, nb_groups, out_channels, out_channels, 1)

    return x


def _pw_group(tensor, nb_groups, in_channels, out_channels):
    """Pointwise grouped convolution."""
    nb_chan_per_grp = in_channels // nb_groups

    pw_convs = []
    for grp in range(nb_groups):
        x = tf.keras.layers.Lambda(lambda x: x[:, :, :, nb_chan_per_grp * grp: nb_chan_per_grp * (grp + 1)])(tensor)
        grp_out_chan = int(out_channels / nb_groups + 0.5)

        pw_convs.append(
            tf.keras.layers.Conv2D(grp_out_chan,
                   kernel_size=(1, 1),
                   padding='same',
                   use_bias=False,
                   strides=1)(x)
        )

    return tf.keras.layers.Concatenate(axis=-1)(pw_convs)


def _shuffle(x, nb_groups):
    def shuffle_layer(x):
        _, w, h, n = tf.keras.backend.int_shape(x)
        nb_chan_per_grp = n // nb_groups

        x = tf.reshape(x, (-1, w, h, nb_chan_per_grp, nb_groups))
        x = tf.keras.backend.permute_dimensions(x, (0, 1, 2, 4, 3)) # Transpose only grps and chs
        x = tf.reshape(x, (-1, w, h, n))

        return x

    return tf.keras.layers.Lambda(shuffle_layer)(x)


def _shufflenet_unit(tensor, nb_groups, in_channels, out_channels, strides, shuffle=True, bottleneck=8):
    bottleneck_channels = out_channels // bottleneck

    x = _pw_group(tensor, nb_groups, in_channels, bottleneck_channels)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    if shuffle:
        x = _shuffle(x, nb_groups)

    x = tf.keras.layers.DepthwiseConv2D(kernel_size=(3, 3),
                        padding='same',
                        use_bias=False,
                        strides=strides)(x)
    x = tf.keras.layers.BatchNormalization()(x)


    x = _pw_group(x, nb_groups, bottleneck_channels,
                  out_channels if strides < 2 else out_channels - in_channels)
    x = tf.keras.layers.BatchNormalization()(x)

    if strides < 2:
        x = tf.keras.layers.Add()([tensor, x])
    else:
        avg = tf.keras.layers.AveragePooling2D(pool_size=(3, 3),
                               strides=2,
                               padding='same')(tensor)

        x = tf.keras.layers.Concatenate(axis=-1)([avg, x])

    x = tf.keras.layers.Activation('relu')(x)

    return x


def _info(nb_groups):
    return {
        1: [24, 144, 288, 576],
        2: [24, 200, 400, 800],
        3: [24, 240, 480, 960],
        4: [24, 272, 544, 1088],
        8: [24, 384, 768, 1536]
    }[nb_groups], [None, 3, 7, 3]


def ShuffleNet(input_shape, nb_classes, include_top=True, weights=None, nb_groups=3):
    x_in = tf.keras.Input(shape=input_shape)

    x = tf.keras.layers.Conv2D(24,
               kernel_size=(3, 3),
               strides=1,
               use_bias=False,
               padding='same')(x_in)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

#     x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3),
#                      strides=2,
#                      padding='same')(x)

    channels_list, repeat_list = _info(nb_groups)
    for i, (out_channels, repeat) in enumerate(zip(channels_list[1:], repeat_list[1:]), start=1):
        x = _stage(x, nb_groups, channels_list[i-1], out_channels, repeat)

    if include_top:
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Dense(nb_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=x_in, outputs=x)

    if weights is not None:
        model.load_weights(weights, by_name=True)

    return model

# %%
model = ShuffleNet((32,32,3),10)
model.summary()
# print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 24)   648         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 24)   96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 24)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 32, 32, 8)    0           activation[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32, 32, 8)    0           activation[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32, 32, 8)    0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 10)   80          lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 10)   80          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 10)   80          lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 30)   0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 30)   120         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 30)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32, 32, 30)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 16, 16, 30)   270         lambda_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 30)   120         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16, 16, 10)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 16, 16, 10)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16, 16, 10)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 72)   720         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 72)   720         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 72)   720         lambda_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 216)  0           conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 16, 16, 24)   0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 216)  864         concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 240)  0           average_pooling2d[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 240)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 16, 16, 80)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 16, 16, 80)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 16, 16, 80)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 10)   800         lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 10)   800         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 10)   800         lambda_9[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 30)   0           conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 30)   120         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 30)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 16, 16, 30)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 16, 16, 30)   270         lambda_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 30)   120         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 80)   800         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 80)   800         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 80)   800         lambda_13[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 240)  0           conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 240)  960         concatenate_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 240)  0           activation_2[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 240)  0           add[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 16, 16, 80)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 16, 16, 80)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 16, 16, 80)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 10)   800         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 10)   800         lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 10)   800         lambda_16[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 30)   0           conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 30)   120         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 30)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 16, 16, 30)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 16, 16, 30)   270         lambda_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 30)   120         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 80)   800         lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 80)   800         lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 80)   800         lambda_20[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 240)  0           conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 240)  960         concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 240)  0           activation_4[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 240)  0           add_1[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 16, 16, 80)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 16, 16, 80)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 16, 16, 80)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 10)   800         lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 10)   800         lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 10)   800         lambda_23[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 30)   0           conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 30)   120         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 30)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 16, 16, 30)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 16, 16, 30)   270         lambda_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 30)   120         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 80)   800         lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 80)   800         lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 80)   800         lambda_27[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 240)  0           conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 240)  960         concatenate_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 240)  0           activation_6[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 240)  0           add_2[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 16, 16, 80)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 16, 16, 80)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 16, 16, 80)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 20)   1600        lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 20)   1600        lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 20)   1600        lambda_30[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 60)   0           conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 60)   240         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 60)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 16, 16, 60)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 8, 8, 60)     540         lambda_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 80)     1600        lambda_32[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 80)     1600        lambda_33[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 80)     1600        lambda_34[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 8, 8, 240)    0           conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 8, 8, 240)    0           activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 240)    960         concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 480)    0           average_pooling2d_1[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 480)    0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 8, 8, 160)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 8, 8, 160)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 8, 8, 160)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 20)     3200        lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 20)     3200        lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 20)     3200        lambda_37[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 8, 8, 60)     0           conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 60)     240         concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 60)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 8, 8, 60)     0           activation_11[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 8, 8, 60)     540         lambda_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 160)    3200        lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 160)    3200        lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 160)    3200        lambda_41[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 8, 8, 480)    0           conv2d_34[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 480)    1920        concatenate_13[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 480)    0           activation_10[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 480)    0           add_3[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 8, 8, 160)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 8, 8, 160)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 8, 8, 160)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 20)     3200        lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 20)     3200        lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 20)     3200        lambda_44[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 8, 8, 60)     0           conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 60)     240         concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 60)     0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 8, 8, 60)     0           activation_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 8, 8, 60)     540         lambda_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 160)    3200        lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 160)    3200        lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 160)    3200        lambda_48[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 8, 8, 480)    0           conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 480)    1920        concatenate_15[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 480)    0           activation_12[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 480)    0           add_4[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 8, 8, 160)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 8, 8, 160)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 8, 8, 160)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 20)     3200        lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 20)     3200        lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 20)     3200        lambda_51[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 8, 8, 60)     0           conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 60)     240         concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 60)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 8, 8, 60)     0           activation_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 8, 8, 60)     540         lambda_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 160)    3200        lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 160)    3200        lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 160)    3200        lambda_55[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 480)    0           conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 480)    1920        concatenate_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 480)    0           activation_14[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 480)    0           add_5[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 8, 8, 160)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 8, 8, 160)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 8, 8, 160)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 20)     3200        lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 20)     3200        lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 20)     3200        lambda_58[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 8, 8, 60)     0           conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 60)     240         concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 60)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 8, 8, 60)     0           activation_17[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 8, 8, 60)     540         lambda_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 160)    3200        lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 160)    3200        lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 160)    3200        lambda_62[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 8, 8, 480)    0           conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 480)    1920        concatenate_19[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 480)    0           activation_16[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 480)    0           add_6[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 8, 8, 160)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 8, 8, 160)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 8, 8, 160)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 20)     3200        lambda_63[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 20)     3200        lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 20)     3200        lambda_65[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 60)     0           conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 60)     240         concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 60)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 8, 8, 60)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 8, 8, 60)     540         lambda_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 4, 4, 480)    1920        concatenate_27[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 4, 4, 960)    0           average_pooling2d_2[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, 4, 960)    0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 4, 4, 320)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 4, 4, 320)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 4, 4, 320)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 4, 4, 40)     12800       lambda_91[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 4, 4, 40)     12800       lambda_92[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 4, 4, 40)     12800       lambda_93[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 4, 4, 120)    0           conv2d_79[0][0]
#                                                                  conv2d_80[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 4, 4, 120)    480         concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 120)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 4, 4, 120)    0           activation_27[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 4, 4, 120)    1080        lambda_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 4, 4, 120)    480         depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 4, 4, 40)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 4, 4, 40)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 4, 4, 40)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 4, 4, 320)    12800       lambda_95[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 4, 4, 320)    12800       lambda_96[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 4, 4, 320)    12800       lambda_97[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 4, 4, 960)    0           conv2d_82[0][0]
#                                                                  conv2d_83[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 4, 4, 960)    3840        concatenate_30[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 960)    0           activation_26[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, 4, 960)    0           add_10[0][0]
# __________________________________________________________________________________________________
# lambda_98 (Lambda)              (None, 4, 4, 320)    0           activation_28[0][0]
# __________________________________________________________________________________________________
# lambda_99 (Lambda)              (None, 4, 4, 320)    0           activation_28[0][0]
# __________________________________________________________________________________________________
# lambda_100 (Lambda)             (None, 4, 4, 320)    0           activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 4, 4, 40)     12800       lambda_98[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 4, 4, 40)     12800       lambda_99[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 4, 4, 40)     12800       lambda_100[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 4, 4, 120)    0           conv2d_85[0][0]
#                                                                  conv2d_86[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 120)    480         concatenate_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, 4, 120)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# lambda_101 (Lambda)             (None, 4, 4, 120)    0           activation_29[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 4, 4, 120)    1080        lambda_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 4, 4, 120)    480         depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# lambda_102 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# lambda_103 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# lambda_104 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 4, 4, 320)    12800       lambda_102[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 4, 4, 320)    12800       lambda_103[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 4, 4, 320)    12800       lambda_104[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 4, 4, 960)    0           conv2d_88[0][0]
#                                                                  conv2d_89[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 4, 4, 960)    3840        concatenate_32[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 960)    0           activation_28[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 960)    0           add_11[0][0]
# __________________________________________________________________________________________________
# lambda_105 (Lambda)             (None, 4, 4, 320)    0           activation_30[0][0]
# __________________________________________________________________________________________________
# lambda_106 (Lambda)             (None, 4, 4, 320)    0           activation_30[0][0]
# __________________________________________________________________________________________________
# lambda_107 (Lambda)             (None, 4, 4, 320)    0           activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 4, 4, 40)     12800       lambda_105[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 4, 4, 40)     12800       lambda_106[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 4, 4, 40)     12800       lambda_107[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 4, 4, 120)    0           conv2d_91[0][0]
#                                                                  conv2d_92[0][0]
#                                                                  conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 120)    480         concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 120)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# lambda_108 (Lambda)             (None, 4, 4, 120)    0           activation_31[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 4, 4, 120)    1080        lambda_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 120)    480         depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# lambda_109 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# lambda_110 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# lambda_111 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 4, 4, 320)    12800       lambda_109[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 4, 4, 320)    12800       lambda_110[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 4, 4, 320)    12800       lambda_111[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 4, 4, 960)    0           conv2d_94[0][0]
#                                                                  conv2d_95[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 960)    3840        concatenate_34[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 960)    0           activation_30[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 960)    0           add_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 960)          0           activation_32[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           9610        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 489,898
# Trainable params: 469,738
# Non-trainable params: 20,160
# __________________________________________________________________________________________________

# %% [markdown]
# #### ShuffleNet training and evaluation.
#
# Trained for 100 epochs and achieved 67.39% accuracy on validaton dataset.
#
# Each epoch takes 18 seconds with a batch size of 512.

# %%
import time
sgd = tf.keras.optimizers.SGD(lr=0.005, decay=4e-5, momentum=0.9, nesterov=True)

# tf.keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy',
                optimizer=sgd,
                metrics=['accuracy'])
reduce_lr_loss = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, epsilon=1e-4, mode='min')
start_time = time.time()
for zz in range(1,num_epochs+1):
  dataset_train = tf.data.TFRecordDataset(filename_train)#.repeat(1)
  dataset_train = dataset_train.apply(tf.data.experimental.shuffle_and_repeat(50000,1))
  dataset_train = dataset_train.apply(tf.data.experimental.map_and_batch(parser,batch_size, num_parallel_calls=batch_size))
#   dataset_train = dataset_train.map(parser, num_parallel_calls=batch_size)
#   dataset_train = dataset_train.shuffle(buffer_size=50000) 
#   dataset_train = dataset_train.batch(batch_size)
  # determine Loss function and Optimizer
  print("TrainEpochs number{}/{}".format(zz,num_epochs))
  
  model.fit_generator(dataset_train,steps_per_epoch=int(50000/batch_size),epochs=1,verbose=1)#, callbacks = [reduce_lr_loss])#,validation_data=dataset_test)

  print("Test Epochs number{}/{}".format(zz,num_epochs))
  model.evaluate_generator(dataset_test,steps=int(10000/batch_size),verbose=1)
  print("  ")
  print("------------------------",time.time()-start_time)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:From <ipython-input-10-3e8db6c2a15b>:12: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# WARNING:tensorflow:From <ipython-input-10-3e8db6c2a15b>:13: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_crop is deprecated. Please use tf.image.random_crop instead.
#
# WARNING:tensorflow:From <ipython-input-4-479aa4c81f5c>:19: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# TrainEpochs number1/200
# 97/97 [==============================] - 104s 1s/step - loss: 2.4252 - acc: 0.1936
# Test Epochs number1/200
# 19/19 [==============================] - 5s 275ms/step - loss: 2.3158 - acc: 0.1004
#
# ------------------------ 109.81078457832336
# TrainEpochs number2/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.9630 - acc: 0.2969
# Test Epochs number2/200
# 19/19 [==============================] - 5s 275ms/step - loss: 2.4009 - acc: 0.1138
#
# ------------------------ 215.42726397514343
# TrainEpochs number3/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.7677 - acc: 0.3492
# Test Epochs number3/200
# 19/19 [==============================] - 5s 276ms/step - loss: 2.5671 - acc: 0.1171
#
# ------------------------ 321.0442976951599
# TrainEpochs number4/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.6621 - acc: 0.3868
# Test Epochs number4/200
# 19/19 [==============================] - 5s 278ms/step - loss: 2.3181 - acc: 0.1919
#
# ------------------------ 426.7161030769348
# TrainEpochs number5/200
# 97/97 [==============================] - 101s 1s/step - loss: 1.6003 - acc: 0.4118
# Test Epochs number5/200
# 19/19 [==============================] - 5s 277ms/step - loss: 1.7996 - acc: 0.3668
#
# ------------------------ 533.0449678897858
# TrainEpochs number6/200
# 97/97 [==============================] - 101s 1s/step - loss: 1.5457 - acc: 0.4335
# Test Epochs number6/200
# 19/19 [==============================] - 5s 279ms/step - loss: 1.5889 - acc: 0.4313
#
# ------------------------ 639.4497425556183
# TrainEpochs number7/200
# 97/97 [==============================] - 101s 1s/step - loss: 1.5202 - acc: 0.4433
# Test Epochs number7/200
# 19/19 [==============================] - 5s 276ms/step - loss: 1.5594 - acc: 0.4454
#
# ------------------------ 745.7433989048004
# TrainEpochs number8/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.4674 - acc: 0.4638
# Test Epochs number8/200
# 19/19 [==============================] - 5s 278ms/step - loss: 1.4928 - acc: 0.4603
#
# ------------------------ 851.6816513538361
# TrainEpochs number9/200
# 97/97 [==============================] - 101s 1s/step - loss: 1.4386 - acc: 0.4789
# Test Epochs number9/200
# 19/19 [==============================] - 5s 277ms/step - loss: 1.5835 - acc: 0.4462
#
# ------------------------ 957.8371725082397
# TrainEpochs number10/200
# 97/97 [==============================] - 101s 1s/step - loss: 1.4025 - acc: 0.4897
# Test Epochs number10/200
# 19/19 [==============================] - 5s 277ms/step - loss: 1.4367 - acc: 0.4965
#
# ------------------------ 1064.0953817367554
# TrainEpochs number11/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.3786 - acc: 0.4992
# Test Epochs number11/200
# 19/19 [==============================] - 5s 275ms/step - loss: 1.3347 - acc: 0.5242
#
# ------------------------ 1169.636502981186
# TrainEpochs number12/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.3455 - acc: 0.5097
# Test Epochs number12/200
# 19/19 [==============================] - 5s 282ms/step - loss: 1.3569 - acc: 0.5216
#
# ------------------------ 1274.8729815483093
# TrainEpochs number13/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.3238 - acc: 0.5190
# Test Epochs number13/200
# 19/19 [==============================] - 5s 276ms/step - loss: 1.3614 - acc: 0.5179
#
# ------------------------ 1380.2635831832886
# TrainEpochs number14/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.2993 - acc: 0.5286
# Test Epochs number14/200
# 19/19 [==============================] - 5s 273ms/step - loss: 1.2596 - acc: 0.5478
#
# ------------------------ 1485.416561126709
# TrainEpochs number15/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.2679 - acc: 0.5407
# Test Epochs number15/200
# 19/19 [==============================] - 5s 274ms/step - loss: 1.2679 - acc: 0.5477
#
# ------------------------ 1591.0008392333984
# TrainEpochs number16/200
# 97/97 [==============================] - 101s 1s/step - loss: 1.2476 - acc: 0.5511
# Test Epochs number16/200
# 19/19 [==============================] - 5s 277ms/step - loss: 1.2880 - acc: 0.5495
#
# ------------------------ 1697.3350825309753
# TrainEpochs number17/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.2282 - acc: 0.5556
# Test Epochs number17/200
# 19/19 [==============================] - 5s 278ms/step - loss: 1.1785 - acc: 0.5820
#
# ------------------------ 1803.2941851615906
# TrainEpochs number18/200
# 97/97 [==============================] - 101s 1s/step - loss: 1.2121 - acc: 0.5625
# Test Epochs number18/200
# 19/19 [==============================] - 5s 278ms/step - loss: 1.2595 - acc: 0.5585
#
# ------------------------ 1909.6916644573212
# TrainEpochs number19/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.1919 - acc: 0.5711
# Test Epochs number19/200
# 19/19 [==============================] - 5s 275ms/step - loss: 1.2005 - acc: 0.5853
#
# ------------------------ 2015.3528156280518
# TrainEpochs number20/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.1758 - acc: 0.5762
# Test Epochs number20/200
# 19/19 [==============================] - 5s 281ms/step - loss: 1.2243 - acc: 0.5690
#
# ------------------------ 2120.6133852005005
# TrainEpochs number21/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.1610 - acc: 0.5814
# Test Epochs number21/200
# 19/19 [==============================] - 5s 276ms/step - loss: 1.2044 - acc: 0.5767
#
# ------------------------ 2226.1652958393097
# TrainEpochs number22/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.1358 - acc: 0.5916
# Test Epochs number22/200
# 19/19 [==============================] - 5s 277ms/step - loss: 1.1301 - acc: 0.5981
#
# ------------------------ 2331.9340946674347
# TrainEpochs number23/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.1261 - acc: 0.5950
# Test Epochs number23/200
# 19/19 [==============================] - 5s 274ms/step - loss: 1.2386 - acc: 0.5834
#
# ------------------------ 2437.588394165039
# TrainEpochs number24/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.1082 - acc: 0.6052
# Test Epochs number24/200
# 19/19 [==============================] - 5s 276ms/step - loss: 1.1215 - acc: 0.6083
#
# ------------------------ 2542.727355003357
# TrainEpochs number25/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.1007 - acc: 0.6023
# Test Epochs number25/200
# 19/19 [==============================] - 5s 277ms/step - loss: 1.1250 - acc: 0.6073
#
# ------------------------ 2648.064822435379
# TrainEpochs number26/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.0861 - acc: 0.6114
# Test Epochs number26/200
# 19/19 [==============================] - 5s 274ms/step - loss: 1.1225 - acc: 0.6113
#
# ------------------------ 2753.446134328842
# TrainEpochs number27/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.0691 - acc: 0.6160
# Test Epochs number27/200
# 19/19 [==============================] - 5s 275ms/step - loss: 1.0535 - acc: 0.6311
#
# ------------------------ 2858.95960187912
# TrainEpochs number28/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.0544 - acc: 0.6226
# Test Epochs number28/200
# 19/19 [==============================] - 5s 278ms/step - loss: 1.0255 - acc: 0.6320
#
# ------------------------ 2964.9002919197083
# TrainEpochs number29/200
# 97/97 [==============================] - 101s 1s/step - loss: 1.0505 - acc: 0.6226
# Test Epochs number29/200
# 19/19 [==============================] - 5s 280ms/step - loss: 1.1512 - acc: 0.6056
#
# ------------------------ 3071.695217370987
# TrainEpochs number30/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.0354 - acc: 0.6280
# Test Epochs number30/200
# 19/19 [==============================] - 5s 279ms/step - loss: 1.0898 - acc: 0.6142
#
# ------------------------ 3177.623309135437
# TrainEpochs number31/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.0236 - acc: 0.6337
# Test Epochs number31/200
# 19/19 [==============================] - 5s 278ms/step - loss: 1.0447 - acc: 0.6316
#
# ------------------------ 3283.234297513962
# TrainEpochs number32/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.0155 - acc: 0.6364
# Test Epochs number32/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.9878 - acc: 0.6511
#
# ------------------------ 3388.8997745513916
# TrainEpochs number33/200
# 97/97 [==============================] - 100s 1s/step - loss: 1.0017 - acc: 0.6395
# Test Epochs number33/200
# 19/19 [==============================] - 5s 275ms/step - loss: 1.0724 - acc: 0.6240
#
# ------------------------ 3493.904299259186
# TrainEpochs number34/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.9916 - acc: 0.6455
# Test Epochs number34/200
# 19/19 [==============================] - 5s 276ms/step - loss: 1.0459 - acc: 0.6365
#
# ------------------------ 3598.8751187324524
# TrainEpochs number35/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.9873 - acc: 0.6481
# Test Epochs number35/200
# 19/19 [==============================] - 5s 273ms/step - loss: 1.0175 - acc: 0.6448
#
# ------------------------ 3704.2622396945953
# TrainEpochs number36/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.9706 - acc: 0.6508
# Test Epochs number36/200
# 19/19 [==============================] - 5s 276ms/step - loss: 1.0281 - acc: 0.6530
#
# ------------------------ 3809.4178173542023
# TrainEpochs number37/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.9637 - acc: 0.6547
# Test Epochs number37/200
# 19/19 [==============================] - 5s 279ms/step - loss: 1.1238 - acc: 0.6144
#
# ------------------------ 3914.8587024211884
# TrainEpochs number38/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.9547 - acc: 0.6601
# Test Epochs number38/200
# 19/19 [==============================] - 5s 276ms/step - loss: 1.0164 - acc: 0.6474
#
# ------------------------ 4020.1493759155273
# TrainEpochs number39/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.9473 - acc: 0.6584
# Test Epochs number39/200
# 19/19 [==============================] - 5s 275ms/step - loss: 1.0536 - acc: 0.6343
#
# ------------------------ 4125.15363240242
# TrainEpochs number40/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.9344 - acc: 0.6666
# Test Epochs number40/200
# 19/19 [==============================] - 5s 282ms/step - loss: 0.9431 - acc: 0.6706
#
# ------------------------ 4231.731430053711
# TrainEpochs number41/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.9295 - acc: 0.6692
# Test Epochs number41/200
# 19/19 [==============================] - 5s 277ms/step - loss: 1.0171 - acc: 0.6501
#
# ------------------------ 4337.486898422241
# TrainEpochs number42/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.9160 - acc: 0.6728
# Test Epochs number42/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.9778 - acc: 0.6703
#
# ------------------------ 4443.410959005356
# TrainEpochs number43/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.9084 - acc: 0.6754
# Test Epochs number43/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.9295 - acc: 0.6754
#
# ------------------------ 4548.999135494232
# TrainEpochs number44/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.9053 - acc: 0.6777
# Test Epochs number44/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.9304 - acc: 0.6791
#
# ------------------------ 4655.050121307373
# TrainEpochs number45/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.8893 - acc: 0.6825
# Test Epochs number45/200
# 19/19 [==============================] - 5s 277ms/step - loss: 1.0010 - acc: 0.6562
#
# ------------------------ 4761.196821451187
# TrainEpochs number46/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.8858 - acc: 0.6834
# Test Epochs number46/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.9110 - acc: 0.6837
#
# ------------------------ 4867.007657289505
# TrainEpochs number47/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.8846 - acc: 0.6839
# Test Epochs number47/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.9885 - acc: 0.6615
#
# ------------------------ 4973.196975946426
# TrainEpochs number48/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.8787 - acc: 0.6879
# Test Epochs number48/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.9768 - acc: 0.6652
#
# ------------------------ 5078.95419383049
# TrainEpochs number49/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.8633 - acc: 0.6916
# Test Epochs number49/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.9449 - acc: 0.6813
#
# ------------------------ 5184.508135557175
# TrainEpochs number50/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.8622 - acc: 0.6915
# Test Epochs number50/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.8816 - acc: 0.6908
#
# ------------------------ 5290.648690223694
# TrainEpochs number51/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.8553 - acc: 0.6951
# Test Epochs number51/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.9822 - acc: 0.6695
#
# ------------------------ 5396.264781951904
# TrainEpochs number52/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.8485 - acc: 0.6974
# Test Epochs number52/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.9080 - acc: 0.6880
#
# ------------------------ 5502.248989105225
# TrainEpochs number53/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.8395 - acc: 0.7031
# Test Epochs number53/200
# 19/19 [==============================] - 5s 272ms/step - loss: 0.8594 - acc: 0.7034
#
# ------------------------ 5607.768311500549
# TrainEpochs number54/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.8347 - acc: 0.7031
# Test Epochs number54/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.8893 - acc: 0.6924
#
# ------------------------ 5713.067508220673
# TrainEpochs number55/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.8272 - acc: 0.7063
# Test Epochs number55/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.9466 - acc: 0.6824
#
# ------------------------ 5818.5330946445465
# TrainEpochs number56/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.8234 - acc: 0.7065
# Test Epochs number56/200
# 19/19 [==============================] - 5s 281ms/step - loss: 0.8802 - acc: 0.7045
#
# ------------------------ 5925.266088724136
# TrainEpochs number57/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.8171 - acc: 0.7102
# Test Epochs number57/200
# 19/19 [==============================] - 5s 281ms/step - loss: 0.9293 - acc: 0.6851
#
# ------------------------ 6031.7007694244385
# TrainEpochs number58/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.8106 - acc: 0.7119
# Test Epochs number58/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.8314 - acc: 0.7153
#
# ------------------------ 6138.435007095337
# TrainEpochs number59/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.8083 - acc: 0.7123
# Test Epochs number59/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.8353 - acc: 0.7118
#
# ------------------------ 6244.450333595276
# TrainEpochs number60/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.8037 - acc: 0.7147
# Test Epochs number60/200
# 19/19 [==============================] - 5s 278ms/step - loss: 1.0618 - acc: 0.6520
#
# ------------------------ 6350.49182009697
# TrainEpochs number61/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7967 - acc: 0.7183
# Test Epochs number61/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.8147 - acc: 0.7206
#
# ------------------------ 6456.188590288162
# TrainEpochs number62/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.7932 - acc: 0.7189
# Test Epochs number62/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.8997 - acc: 0.6895
#
# ------------------------ 6562.596176147461
# TrainEpochs number63/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.7902 - acc: 0.7188
# Test Epochs number63/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.8065 - acc: 0.7272
#
# ------------------------ 6668.831275701523
# TrainEpochs number64/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.7828 - acc: 0.7235
# Test Epochs number64/200
# 19/19 [==============================] - 5s 273ms/step - loss: 0.9617 - acc: 0.6767
#
# ------------------------ 6774.768567323685
# TrainEpochs number65/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7824 - acc: 0.7206
# Test Epochs number65/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.8171 - acc: 0.7214
#
# ------------------------ 6880.296359539032
# TrainEpochs number66/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7751 - acc: 0.7248
# Test Epochs number66/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.9162 - acc: 0.6885
#
# ------------------------ 6985.546205043793
# TrainEpochs number67/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7749 - acc: 0.7255
# Test Epochs number67/200
# 19/19 [==============================] - 5s 274ms/step - loss: 0.8973 - acc: 0.6980
#
# ------------------------ 7091.228744268417
# TrainEpochs number68/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7605 - acc: 0.7302
# Test Epochs number68/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.9391 - acc: 0.6919
#
# ------------------------ 7196.239638566971
# TrainEpochs number69/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7615 - acc: 0.7282
# Test Epochs number69/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.8526 - acc: 0.7118
#
# ------------------------ 7301.472813129425
# TrainEpochs number70/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.7537 - acc: 0.7340
# Test Epochs number70/200
# 19/19 [==============================] - 5s 282ms/step - loss: 0.8290 - acc: 0.7217
#
# ------------------------ 7407.765598297119
# TrainEpochs number71/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.7566 - acc: 0.7323
# Test Epochs number71/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.8640 - acc: 0.7137
#
# ------------------------ 7513.822069883347
# TrainEpochs number72/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7448 - acc: 0.7358
# Test Epochs number72/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.8747 - acc: 0.7101
#
# ------------------------ 7619.090215921402
# TrainEpochs number73/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7457 - acc: 0.7342
# Test Epochs number73/200
# 19/19 [==============================] - 5s 282ms/step - loss: 0.8780 - acc: 0.7053
#
# ------------------------ 7724.602194070816
# TrainEpochs number74/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7440 - acc: 0.7375
# Test Epochs number74/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.8444 - acc: 0.7111
#
# ------------------------ 7830.213748216629
# TrainEpochs number75/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7391 - acc: 0.7383
# Test Epochs number75/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7907 - acc: 0.7264
#
# ------------------------ 7935.932268857956
# TrainEpochs number76/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7345 - acc: 0.7404
# Test Epochs number76/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7935 - acc: 0.7284
#
# ------------------------ 8041.7592396736145
# TrainEpochs number77/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.7268 - acc: 0.7402
# Test Epochs number77/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.7921 - acc: 0.7291
#
# ------------------------ 8148.003148317337
# TrainEpochs number78/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.7248 - acc: 0.7411
# Test Epochs number78/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7993 - acc: 0.7295
#
# ------------------------ 8254.090461015701
# TrainEpochs number79/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7203 - acc: 0.7454
# Test Epochs number79/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.8584 - acc: 0.7227
#
# ------------------------ 8359.656605958939
# TrainEpochs number80/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7184 - acc: 0.7430
# Test Epochs number80/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.8346 - acc: 0.7183
#
# ------------------------ 8464.861074447632
# TrainEpochs number81/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7165 - acc: 0.7467
# Test Epochs number81/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7872 - acc: 0.7355
#
# ------------------------ 8570.217740535736
# TrainEpochs number82/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7096 - acc: 0.7483
# Test Epochs number82/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7558 - acc: 0.7472
#
# ------------------------ 8675.547957658768
# TrainEpochs number83/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7090 - acc: 0.7488
# Test Epochs number83/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7968 - acc: 0.7290
#
# ------------------------ 8781.416449069977
# TrainEpochs number84/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7045 - acc: 0.7507
# Test Epochs number84/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7490 - acc: 0.7458
#
# ------------------------ 8886.772404670715
# TrainEpochs number85/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.7035 - acc: 0.7511
# Test Epochs number85/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7222 - acc: 0.7523
#
# ------------------------ 8992.145095825195
# TrainEpochs number86/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6946 - acc: 0.7539
# Test Epochs number86/200
# 19/19 [==============================] - 5s 275ms/step - loss: 1.0112 - acc: 0.6873
#
# ------------------------ 9097.22311425209
# TrainEpochs number87/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6913 - acc: 0.7543
# Test Epochs number87/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.7933 - acc: 0.7388
#
# ------------------------ 9202.632798433304
# TrainEpochs number88/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6961 - acc: 0.7549
# Test Epochs number88/200
# 19/19 [==============================] - 5s 281ms/step - loss: 0.8734 - acc: 0.7122
#
# ------------------------ 9308.70759344101
# TrainEpochs number89/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6856 - acc: 0.7561
# Test Epochs number89/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7441 - acc: 0.7522
#
# ------------------------ 9414.773240566254
# TrainEpochs number90/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6894 - acc: 0.7557
# Test Epochs number90/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.8618 - acc: 0.7185
#
# ------------------------ 9521.083465337753
# TrainEpochs number91/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6830 - acc: 0.7583
# Test Epochs number91/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.8170 - acc: 0.7302
#
# ------------------------ 9627.95847582817
# TrainEpochs number92/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6811 - acc: 0.7604
# Test Epochs number92/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7351 - acc: 0.7522
#
# ------------------------ 9734.113690137863
# TrainEpochs number93/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6796 - acc: 0.7582
# Test Epochs number93/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.7955 - acc: 0.7354
#
# ------------------------ 9840.352736473083
# TrainEpochs number94/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6758 - acc: 0.7609
# Test Epochs number94/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.7677 - acc: 0.7496
#
# ------------------------ 9947.131301879883
# TrainEpochs number95/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6730 - acc: 0.7605
# Test Epochs number95/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7364 - acc: 0.7536
#
# ------------------------ 10053.390012741089
# TrainEpochs number96/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6733 - acc: 0.7613
# Test Epochs number96/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.7463 - acc: 0.7498
#
# ------------------------ 10159.216637134552
# TrainEpochs number97/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6636 - acc: 0.7640
# Test Epochs number97/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.8189 - acc: 0.7294
#
# ------------------------ 10264.960567712784
# TrainEpochs number98/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6665 - acc: 0.7646
# Test Epochs number98/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7409 - acc: 0.7527
#
# ------------------------ 10370.448260068893
# TrainEpochs number99/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6611 - acc: 0.7653
# Test Epochs number99/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.7800 - acc: 0.7406
#
# ------------------------ 10476.287461042404
# TrainEpochs number100/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6576 - acc: 0.7650
# Test Epochs number100/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7515 - acc: 0.7499
#
# ------------------------ 10582.13003897667
# TrainEpochs number101/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6549 - acc: 0.7696
# Test Epochs number101/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.7434 - acc: 0.7533
#
# ------------------------ 10687.94398021698
# TrainEpochs number102/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6539 - acc: 0.7699
# Test Epochs number102/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.7504 - acc: 0.7536
#
# ------------------------ 10793.975486040115
# TrainEpochs number103/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6481 - acc: 0.7710
# Test Epochs number103/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7043 - acc: 0.7646
#
# ------------------------ 10899.46412563324
# TrainEpochs number104/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6434 - acc: 0.7709
# Test Epochs number104/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7637 - acc: 0.7459
#
# ------------------------ 11005.342782974243
# TrainEpochs number105/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6435 - acc: 0.7703
# Test Epochs number105/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.7393 - acc: 0.7562
#
# ------------------------ 11110.99215221405
# TrainEpochs number106/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6357 - acc: 0.7764
# Test Epochs number106/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7824 - acc: 0.7436
#
# ------------------------ 11216.654344081879
# TrainEpochs number107/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.6409 - acc: 0.7719
# Test Epochs number107/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7409 - acc: 0.7503
#
# ------------------------ 11322.829782009125
# TrainEpochs number108/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6375 - acc: 0.7734
# Test Epochs number108/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.8118 - acc: 0.7362
#
# ------------------------ 11428.238965034485
# TrainEpochs number109/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6341 - acc: 0.7745
# Test Epochs number109/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7433 - acc: 0.7502
#
# ------------------------ 11533.30548787117
# TrainEpochs number110/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6288 - acc: 0.7788
# Test Epochs number110/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7689 - acc: 0.7510
#
# ------------------------ 11638.510890722275
# TrainEpochs number111/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6303 - acc: 0.7762
# Test Epochs number111/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.8273 - acc: 0.7275
#
# ------------------------ 11743.999286174774
# TrainEpochs number112/200
# 97/97 [==============================] - 99s 1s/step - loss: 0.6282 - acc: 0.7785
# Test Epochs number112/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7189 - acc: 0.7553
#
# ------------------------ 11848.81188416481
# TrainEpochs number113/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6245 - acc: 0.7799
# Test Epochs number113/200
# 19/19 [==============================] - 5s 275ms/step - loss: 1.0167 - acc: 0.6937
#
# ------------------------ 11953.902794122696
# TrainEpochs number114/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6229 - acc: 0.7802
# Test Epochs number114/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.7030 - acc: 0.7627
#
# ------------------------ 12059.325515270233
# TrainEpochs number115/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6169 - acc: 0.7812
# Test Epochs number115/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7155 - acc: 0.7611
#
# ------------------------ 12165.108613491058
# TrainEpochs number116/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6197 - acc: 0.7811
# Test Epochs number116/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7435 - acc: 0.7529
#
# ------------------------ 12270.661333322525
# TrainEpochs number117/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6178 - acc: 0.7838
# Test Epochs number117/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.7520 - acc: 0.7538
#
# ------------------------ 12375.83577632904
# TrainEpochs number118/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6110 - acc: 0.7852
# Test Epochs number118/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.8629 - acc: 0.7291
#
# ------------------------ 12481.0326089859
# TrainEpochs number119/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6121 - acc: 0.7838
# Test Epochs number119/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6880 - acc: 0.7740
#
# ------------------------ 12586.740647554398
# TrainEpochs number120/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6115 - acc: 0.7816
# Test Epochs number120/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.6965 - acc: 0.7692
#
# ------------------------ 12692.026486873627
# TrainEpochs number121/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6170 - acc: 0.7820
# Test Epochs number121/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6678 - acc: 0.7752
#
# ------------------------ 12797.044464111328
# TrainEpochs number122/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6050 - acc: 0.7857
# Test Epochs number122/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7461 - acc: 0.7507
#
# ------------------------ 12902.377438545227
# TrainEpochs number123/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6038 - acc: 0.7871
# Test Epochs number123/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6795 - acc: 0.7788
#
# ------------------------ 13007.749989748001
# TrainEpochs number124/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.6047 - acc: 0.7845
# Test Epochs number124/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.9220 - acc: 0.7130
#
# ------------------------ 13112.78791809082
# TrainEpochs number125/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5982 - acc: 0.7889
# Test Epochs number125/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6869 - acc: 0.7744
#
# ------------------------ 13217.920146226883
# TrainEpochs number126/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.5999 - acc: 0.7875
# Test Epochs number126/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.7087 - acc: 0.7681
#
# ------------------------ 13323.946500062943
# TrainEpochs number127/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5966 - acc: 0.7884
# Test Epochs number127/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6935 - acc: 0.7714
#
# ------------------------ 13429.426649570465
# TrainEpochs number128/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5979 - acc: 0.7891
# Test Epochs number128/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6759 - acc: 0.7714
#
# ------------------------ 13534.777261018753
# TrainEpochs number129/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5892 - acc: 0.7903
# Test Epochs number129/200
# 19/19 [==============================] - 5s 282ms/step - loss: 0.7561 - acc: 0.7586
#
# ------------------------ 13640.099581956863
# TrainEpochs number130/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.5903 - acc: 0.7905
# Test Epochs number130/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.6640 - acc: 0.7810
#
# ------------------------ 13746.21109032631
# TrainEpochs number131/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.5936 - acc: 0.7906
# Test Epochs number131/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.7002 - acc: 0.7699
#
# ------------------------ 13852.219369411469
# TrainEpochs number132/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5906 - acc: 0.7926
# Test Epochs number132/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.7292 - acc: 0.7628
#
# ------------------------ 13958.030292749405
# TrainEpochs number133/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5901 - acc: 0.7914
# Test Epochs number133/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6767 - acc: 0.7783
#
# ------------------------ 14063.84434390068
# TrainEpochs number134/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5784 - acc: 0.7970
# Test Epochs number134/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.6495 - acc: 0.7840
#
# ------------------------ 14169.116653680801
# TrainEpochs number135/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5817 - acc: 0.7950
# Test Epochs number135/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6655 - acc: 0.7817
#
# ------------------------ 14274.4425137043
# TrainEpochs number136/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5791 - acc: 0.7947
# Test Epochs number136/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7450 - acc: 0.7582
#
# ------------------------ 14379.98173737526
# TrainEpochs number137/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5809 - acc: 0.7946
# Test Epochs number137/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.6979 - acc: 0.7707
#
# ------------------------ 14485.5365858078
# TrainEpochs number138/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.5790 - acc: 0.7940
# Test Epochs number138/200
# 19/19 [==============================] - 5s 277ms/step - loss: 1.0564 - acc: 0.6882
#
# ------------------------ 14591.839384317398
# TrainEpochs number139/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5762 - acc: 0.7962
# Test Epochs number139/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6866 - acc: 0.7745
#
# ------------------------ 14697.15632557869
# TrainEpochs number140/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5749 - acc: 0.7952
# Test Epochs number140/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6993 - acc: 0.7676
#
# ------------------------ 14802.641052484512
# TrainEpochs number141/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5710 - acc: 0.7965
# Test Epochs number141/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.6525 - acc: 0.7824
#
# ------------------------ 14907.76098394394
# TrainEpochs number142/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5673 - acc: 0.7980
# Test Epochs number142/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7211 - acc: 0.7636
#
# ------------------------ 15013.364741325378
# TrainEpochs number143/200
# 97/97 [==============================] - 101s 1s/step - loss: 0.5707 - acc: 0.7989
# Test Epochs number143/200
# 19/19 [==============================] - 5s 280ms/step - loss: 0.6414 - acc: 0.7871
#
# ------------------------ 15119.457397460938
# TrainEpochs number144/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5657 - acc: 0.8004
# Test Epochs number144/200
# 19/19 [==============================] - 5s 281ms/step - loss: 0.6770 - acc: 0.7814
#
# ------------------------ 15224.957659959793
# TrainEpochs number145/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5659 - acc: 0.7988
# Test Epochs number145/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.6765 - acc: 0.7775
#
# ------------------------ 15330.533271074295
# TrainEpochs number146/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5634 - acc: 0.7981
# Test Epochs number146/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6544 - acc: 0.7819
#
# ------------------------ 15436.095125198364
# TrainEpochs number147/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5636 - acc: 0.7983
# Test Epochs number147/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7924 - acc: 0.7413
#
# ------------------------ 15541.277040243149
# TrainEpochs number148/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5593 - acc: 0.8004
# Test Epochs number148/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7254 - acc: 0.7663
#
# ------------------------ 15646.5008020401
# TrainEpochs number149/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5595 - acc: 0.8032
# Test Epochs number149/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6878 - acc: 0.7754
#
# ------------------------ 15751.528023719788
# TrainEpochs number150/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5593 - acc: 0.8002
# Test Epochs number150/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6823 - acc: 0.7789
#
# ------------------------ 15856.565257787704
# TrainEpochs number151/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5565 - acc: 0.8036
# Test Epochs number151/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6678 - acc: 0.7845
#
# ------------------------ 15961.96182346344
# TrainEpochs number152/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5533 - acc: 0.8059
# Test Epochs number152/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7020 - acc: 0.7703
#
# ------------------------ 16067.000788211823
# TrainEpochs number153/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5535 - acc: 0.8040
# Test Epochs number153/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.9654 - acc: 0.7069
#
# ------------------------ 16172.152141809464
# TrainEpochs number154/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5529 - acc: 0.8035
# Test Epochs number154/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.6712 - acc: 0.7775
#
# ------------------------ 16277.246263027191
# TrainEpochs number155/200
# 97/97 [==============================] - 99s 1s/step - loss: 0.5440 - acc: 0.8078
# Test Epochs number155/200
# 19/19 [==============================] - 5s 273ms/step - loss: 0.7099 - acc: 0.7695
#
# ------------------------ 16382.120244979858
# TrainEpochs number156/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5479 - acc: 0.8062
# Test Epochs number156/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6717 - acc: 0.7795
#
# ------------------------ 16487.226363897324
# TrainEpochs number157/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5435 - acc: 0.8089
# Test Epochs number157/200
# 19/19 [==============================] - 5s 273ms/step - loss: 0.6321 - acc: 0.7916
#
# ------------------------ 16592.451504468918
# TrainEpochs number158/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5465 - acc: 0.8075
# Test Epochs number158/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7182 - acc: 0.7756
#
# ------------------------ 16697.511325597763
# TrainEpochs number159/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5438 - acc: 0.8075
# Test Epochs number159/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6555 - acc: 0.7866
#
# ------------------------ 16802.89216852188
# TrainEpochs number160/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5414 - acc: 0.8081
# Test Epochs number160/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6256 - acc: 0.7961
#
# ------------------------ 16907.932489156723
# TrainEpochs number161/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5397 - acc: 0.8082
# Test Epochs number161/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6659 - acc: 0.7777
#
# ------------------------ 17012.935049295425
# TrainEpochs number162/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5342 - acc: 0.8098
# Test Epochs number162/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7467 - acc: 0.7634
#
# ------------------------ 17117.925381183624
# TrainEpochs number163/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5373 - acc: 0.8091
# Test Epochs number163/200
# 19/19 [==============================] - 5s 274ms/step - loss: 0.6766 - acc: 0.7790
#
# ------------------------ 17223.143487215042
# TrainEpochs number164/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5371 - acc: 0.8119
# Test Epochs number164/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6476 - acc: 0.7835
#
# ------------------------ 17328.274162769318
# TrainEpochs number165/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5319 - acc: 0.8099
# Test Epochs number165/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7361 - acc: 0.7618
#
# ------------------------ 17433.374808311462
# TrainEpochs number166/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5375 - acc: 0.8080
# Test Epochs number166/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6673 - acc: 0.7856
#
# ------------------------ 17538.70204257965
# TrainEpochs number167/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5350 - acc: 0.8089
# Test Epochs number167/200
# 19/19 [==============================] - 5s 274ms/step - loss: 0.6291 - acc: 0.7963
#
# ------------------------ 17643.947712421417
# TrainEpochs number168/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5326 - acc: 0.8128
# Test Epochs number168/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7040 - acc: 0.7722
#
# ------------------------ 17749.21036505699
# TrainEpochs number169/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5281 - acc: 0.8131
# Test Epochs number169/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6632 - acc: 0.7845
#
# ------------------------ 17854.914131879807
# TrainEpochs number170/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5278 - acc: 0.8120
# Test Epochs number170/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6488 - acc: 0.7889
#
# ------------------------ 17960.09194135666
# TrainEpochs number171/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5284 - acc: 0.8149
# Test Epochs number171/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6802 - acc: 0.7786
#
# ------------------------ 18065.160542488098
# TrainEpochs number172/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5206 - acc: 0.8153
# Test Epochs number172/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6899 - acc: 0.7805
#
# ------------------------ 18170.181969881058
# TrainEpochs number173/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5272 - acc: 0.8139
# Test Epochs number173/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7538 - acc: 0.7594
#
# ------------------------ 18275.36752796173
# TrainEpochs number174/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5237 - acc: 0.8151
# Test Epochs number174/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.6838 - acc: 0.7830
#
# ------------------------ 18380.45482325554
# TrainEpochs number175/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5228 - acc: 0.8149
# Test Epochs number175/200
# 19/19 [==============================] - 5s 274ms/step - loss: 0.6391 - acc: 0.7871
#
# ------------------------ 18485.90241074562
# TrainEpochs number176/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5201 - acc: 0.8165
# Test Epochs number176/200
# 19/19 [==============================] - 5s 274ms/step - loss: 0.6206 - acc: 0.7929
#
# ------------------------ 18590.960854530334
# TrainEpochs number177/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5196 - acc: 0.8146
# Test Epochs number177/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6582 - acc: 0.7835
#
# ------------------------ 18696.204926729202
# TrainEpochs number178/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5177 - acc: 0.8164
# Test Epochs number178/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6276 - acc: 0.7972
#
# ------------------------ 18801.63722872734
# TrainEpochs number179/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5165 - acc: 0.8167
# Test Epochs number179/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6504 - acc: 0.7884
#
# ------------------------ 18907.12277984619
# TrainEpochs number180/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5182 - acc: 0.8179
# Test Epochs number180/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6405 - acc: 0.7914
#
# ------------------------ 19012.241186380386
# TrainEpochs number181/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5187 - acc: 0.8154
# Test Epochs number181/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6648 - acc: 0.7832
#
# ------------------------ 19117.263200759888
# TrainEpochs number182/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5118 - acc: 0.8167
# Test Epochs number182/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6774 - acc: 0.7811
#
# ------------------------ 19222.435364484787
# TrainEpochs number183/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5159 - acc: 0.8177
# Test Epochs number183/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6898 - acc: 0.7787
#
# ------------------------ 19327.503265857697
# TrainEpochs number184/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5124 - acc: 0.8196
# Test Epochs number184/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.6465 - acc: 0.7898
#
# ------------------------ 19433.16334939003
# TrainEpochs number185/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5154 - acc: 0.8194
# Test Epochs number185/200
# 19/19 [==============================] - 5s 274ms/step - loss: 0.6263 - acc: 0.7981
#
# ------------------------ 19539.015038490295
# TrainEpochs number186/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5084 - acc: 0.8206
# Test Epochs number186/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.6463 - acc: 0.7898
#
# ------------------------ 19644.309311389923
# TrainEpochs number187/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5049 - acc: 0.8215
# Test Epochs number187/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.7443 - acc: 0.7639
#
# ------------------------ 19749.911206007004
# TrainEpochs number188/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5062 - acc: 0.8214
# Test Epochs number188/200
# 19/19 [==============================] - 5s 273ms/step - loss: 0.6434 - acc: 0.7925
#
# ------------------------ 19855.063755750656
# TrainEpochs number189/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5108 - acc: 0.8201
# Test Epochs number189/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.7115 - acc: 0.7713
#
# ------------------------ 19960.075175762177
# TrainEpochs number190/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5062 - acc: 0.8197
# Test Epochs number190/200
# 19/19 [==============================] - 5s 279ms/step - loss: 0.6393 - acc: 0.7920
#
# ------------------------ 20065.232162237167
# TrainEpochs number191/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5069 - acc: 0.8197
# Test Epochs number191/200
# 19/19 [==============================] - 5s 277ms/step - loss: 0.6381 - acc: 0.7992
#
# ------------------------ 20170.682766199112
# TrainEpochs number192/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5051 - acc: 0.8212
# Test Epochs number192/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.6399 - acc: 0.7921
#
# ------------------------ 20276.12071967125
# TrainEpochs number193/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5035 - acc: 0.8216
# Test Epochs number193/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.6836 - acc: 0.7841
#
# ------------------------ 20381.374778032303
# TrainEpochs number194/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.4985 - acc: 0.8239
# Test Epochs number194/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6415 - acc: 0.7919
#
# ------------------------ 20486.721198558807
# TrainEpochs number195/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.5024 - acc: 0.8225
# Test Epochs number195/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.7030 - acc: 0.7759
#
# ------------------------ 20591.67282962799
# TrainEpochs number196/200
# 97/97 [==============================] - 99s 1s/step - loss: 0.4979 - acc: 0.8252
# Test Epochs number196/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6739 - acc: 0.7837
#
# ------------------------ 20696.510471105576
# TrainEpochs number197/200
# 97/97 [==============================] - 99s 1s/step - loss: 0.4961 - acc: 0.8241
# Test Epochs number197/200
# 19/19 [==============================] - 5s 274ms/step - loss: 0.6616 - acc: 0.7841
#
# ------------------------ 20801.28634238243
# TrainEpochs number198/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.4935 - acc: 0.8260
# Test Epochs number198/200
# 19/19 [==============================] - 5s 278ms/step - loss: 0.6948 - acc: 0.7777
#
# ------------------------ 20906.343244552612
# TrainEpochs number199/200
# 97/97 [==============================] - 100s 1s/step - loss: 0.4955 - acc: 0.8246
# Test Epochs number199/200
# 19/19 [==============================] - 5s 276ms/step - loss: 0.6536 - acc: 0.7878
#
# ------------------------ 21011.407888412476
# TrainEpochs number200/200
# 97/97 [==============================] - 99s 1s/step - loss: 0.4894 - acc: 0.8259
# Test Epochs number200/200
# 19/19 [==============================] - 5s 274ms/step - loss: 0.6646 - acc: 0.7834
#
# ------------------------ 21116.104242563248

# %%
# !nvidia-smi
# Out:
# Fri Oct 18 01:03:13 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.40       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P0    59W / 149W |  11034MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #### VISUALIZING CUTOUT

# %%
batch_size = 5

dataset_train = tf.data.TFRecordDataset(filename_train).repeat(1)
# dataset_test = dataset_train.apply(tf.contrib.data.shuffle_and_repeat(1,40000))
# dataset_test = dataset_train.apply(tf.contrib.data.map_and_batch(parser,batch_size))
dataset_train = dataset_train.map(parser, num_parallel_calls=batch_size)
dataset_train = dataset_train.shuffle(buffer_size=40000) 
dataset_train = dataset_train.batch(batch_size)

# %%
% matplotlib inline
z=0
fig, ax = plt.subplots(3,5, figsize=(10,10))
for j,i in enumerate(dataset_train):
#     print("test",i[0].shape,i[1].shape,j)
    for l,k in enumerate(i[0]):
#         print(k.shape)
#         print(z,l)
        ax[z,l].imshow(k)
        ax[z,l].set_title("ORIGINAL")
    z += 1
    if z == 3:  
      break

# %% [markdown]
# #### MISS-CLASSIFIED IMAGES

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
import numpy as np
import matplotlib.pyplot as plt

j,t = 0, 0
X_test_wrong = []
X_test_wrong_raw = []
for i in range(len(test_features)):
  img_data = test_features[i].astype('float32')
  img_data /= 255
  img_data = np.expand_dims(img_data, axis=0)
#   img_data = test_features[i].reshape(1, 32, 32,3)
  t += 1
#   print(model.predict(img_data)[0])
#   print(np.argmax(model.predict(img_data)[0]))
#   print(test_labels[i][0])
  if np.argmax(model.predict(img_data)[0]) != test_labels[i][0]:
    X_test_wrong.append((img_data, np.argmax(model.predict(img_data)[0]), test_labels[i][0]))
    X_test_wrong_raw.append((test_features[i], np.argmax(model.predict(img_data)[0]), test_labels[i][0]))
    j += 1
  if j >= 50:
    break
print('totla false preds {} for samples {}'.format(j,t))
# Out:
# totla false preds 50 for samples 259

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

# %%
plt.figure(figsize=(35,35))
batch_size = 25
i = 0
for img in X_test_wrong:
  ax = plt.subplot(10,5,i+1)
  ax.set_title("pred: {}   actu: {}".format(class_names[img[1]], class_names[img[2]]), color='r')
  plt.imshow(np.reshape(np.uint8(255 * img[0]), (32,32,-1)), cmap=plt.cm.gray)
  i += 1
